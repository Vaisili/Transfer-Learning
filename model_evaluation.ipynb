# %%
import torch
import numpy as np
from torchvision import datasets, transforms
from model import ResNetFashion
from data_loader import FashionDataset

# %%
def calc(model, dataset_loader, train_label_map, test_label_map, batch_size=1):
    top1_classes = {}
    top5_classes = {}
    totals = {}
    model.eval()
    for i, (data, target) in enumerate(dataset_loader):
        reversed_map = {v:k for k,v in test_label_map.items()}
        rev_map_train = {v:k for k,v in train_label_map.items()}
        key = reversed_map[target[0].item()]
        if key in train_label_map.keys():  # consider classes present in train set only
            if key not in totals:
                totals[key] = 1
            else:
                totals[key] += 1
            print("Target", reversed_map[target[0].item()])
            if cuda:
                data, target = data.cuda(), target.cuda()
            output = model(data)
            _, pred = torch.max(output, 1)
            output_idx = output.argmax(dim=1, keepdim=True)
            print("Predicted: ", rev_map_train[output_idx[0].item()])
            top1 = rev_map_train[output_idx[0].item()] == reversed_map[target[0].item()]
            top5 = (output.topk(5)[1]==train_label_map[reversed_map[target[0].item()]]).nonzero().numel()>0
            if top1:
                if key not in top1_classes:
                    top1_classes[key]= 1
                else:
                    top1_classes[key] += 1
            if top5:
                if key not in top5_classes:
                    top5_classes[key]= 1
                else:
                    top5_classes[key] += 1
            if i%1000==0:
                print(i)
          
    
    print("Total Instances: ", sum(list(totals.values())))
    print("Overall Accuracy: ", sum(list(top1_classes.values()))/sum(list(totals.values())))
    for lbl in top1_classes:
        print("class: \n", lbl)
        print("top1: ", top1_classes[lbl]/totals[lbl])
        print("top5: ", top5_classes[lbl]/totals[lbl])

# %%
from data_loader import FashionDataset
cuda = torch.cuda.is_available()

transforms_ = transforms.Compose([transforms.Resize((224,224)), transforms.ToTensor()])
data = FashionDataset("D:\\Projects\\Datasets\\fashion-larger","test_set.csv", transform=transforms_)
dataset_loader = torch.utils.data.DataLoader(dataset=data, batch_size=1)
model = ResNetFashion(num_classes=88)
model.cuda()
cp = torch.load("D:\\Projects\\Datasets\\fashion-larger\\model_output\\remainingclasses_loss_weight_sgd\\fashion-4.pth")
label_map = cp['label_map']
# label_map = {'Watches': 0, 'Tshirts': 1, 'Shirts': 2, 'Socks': 3, 'Belts': 4, 'Handbags': 5, 'Flip Flops': 6, 'Tops': 7, 'Casual Shoes': 8, 'Flats': 9, 'Kurtas': 10, 'Sports Shoes': 11, 'Briefs': 12, 'Formal Shoes': 13, 'Sarees': 14, 'Heels': 15, 'Sunglasses': 16, 'Dresses': 17, 'Wallets': 18, 'Sandals': 19}
model.load_state_dict(cp['state_dict'])
calc(model,dataset_loader, label_map, data.label_map)
# Out:
# Found 20635 images in D:\Projects\Datasets\fashion-larger for provided csv file.
# Total classes: 122
# Target Track Pants
# Predicted:  Track Pants
# Target Shoe Accessories
# Predicted:  Bangle
# Target Sweatshirts
# Predicted:  Sweatshirts
# Target Waistcoat
# Predicted:  Blazers
# Target Shorts
# Predicted:  Shorts
# Target Sweatshirts
# Predicted:  Sweatshirts
# Target Night suits
# Predicted:  Kurta Sets
# Target Sweatshirts
# Predicted:  Sweatshirts
# Target Clutches
# Predicted:  Clutches
# Target Backpacks
# Predicted:  Backpacks
# Target Caps
# Predicted:  Caps
# Target Trousers
# Predicted:  Trousers
# Target Sweatshirts
# Predicted:  Blazers
# Target Shorts
# Predicted:  Shorts
# Target Camisoles
# Predicted:  Bra
# Target Jeans
# Predicted:  Jeans
# Target Dupatta
# Predicted:  Scarves
# Target Track Pants
# Predicted:  Track Pants
# Target Bra
# Predicted:  Bra
# Target Shorts
# Predicted:  Shorts
# Target Mufflers
# Predicted:  Scarves
# Target Jackets
# Predicted:  Dupatta
# Target Lounge Pants
# Predicted:  Lounge Pants
# Target Duffel Bag
# Predicted:  Duffel Bag
# Target Backpacks
# Predicted:  Backpacks
# Target Track Pants
# Predicted:  Track Pants
# Target Jeans
# Predicted:  Jeans
# Target Sweaters
# Predicted:  Nehru Jackets
# Target Trousers
# Predicted:  Track Pants
# Target Night suits
# Predicted:  Night suits
# Target Jeans
# Predicted:  Track Pants
# Target Backpacks
# Predicted:  Backpacks
# Target Lounge Pants
# Predicted:  Track Pants
# Target Backpacks
# Predicted:  Backpacks
# Target Pendant
# Predicted:  Pendant
# Target Jeans
# Predicted:  Jeans
# Target Tracksuits
# Predicted:  Tracksuits
# Target Track Pants
# Predicted:  Track Pants
# Target Pendant
# Predicted:  Jewellery Set
# Target Capris
# Predicted:  Track Pants
# Target Bra
# Predicted:  Bra
# Target Clutches
# Predicted:  Clutches
# Target Duffel Bag
# Predicted:  Duffel Bag
# Target Track Pants
# Predicted:  Track Pants
# Target Caps
# Predicted:  Caps
# Target Backpacks
# Predicted:  Backpacks
# Target Shorts
# Predicted:  Capris
# Target Jeans
# Predicted:  Jeans
# Target Bra
# Predicted:  Bra
# Target Mufflers
# Predicted:  Scarves
# Target Tunics
# Predicted:  Tunics
# Target Caps
# Predicted:  Caps
# Target Track Pants
# Predicted:  Track Pants
# Target Nightdress
# Predicted:  Nightdress
# Target Ties
# Predicted:  Ties
# Target Bra
# Predicted:  Bra
# Target Bra
# Predicted:  Bra
# Target Leggings
# Predicted:  Leggings
# Target Caps
# Predicted:  Caps
# Target Sweatshirts
# Predicted:  Sweatshirts
# Target Trousers
# Predicted:  Trousers
# Target Backpacks
# Predicted:  Backpacks
# Target Travel Accessory
# Predicted:  Backpacks
# Target Bra
# Predicted:  Bra
# Target Jackets
# Predicted:  Shrug
# Target Jackets
# Predicted:  Jackets
# Target Sweaters
# Predicted:  Sweatshirts
# Target Camisoles
# Predicted:  Bra
# Target Travel Accessory
# Predicted:  Backpacks
# Target Caps
# Predicted:  Caps
# Target Trousers
# Predicted:  Track Pants
# Target Bangle
# Predicted:  Bracelet
# Target Jackets
# Predicted:  Waistcoat
# Target Sweatshirts
# Predicted:  Sweatshirts
# Target Mufflers
# Predicted:  Scarves
# Target Nightdress
# Predicted:  Nightdress
# Target Messenger Bag
# Predicted:  Backpacks
# Target Jeans
# Predicted:  Jeans
# Target Messenger Bag
# Predicted:  Messenger Bag
# Target Mufflers
# Predicted:  Mufflers
# Target Sweaters
# Predicted:  Sweatshirts
# Target Sweatshirts
# Predicted:  Sweatshirts
# Target Leggings
# Predicted:  Jeans
# Target Kurta Sets
# Predicted:  Kurta Sets
# Target Pendant
# Predicted:  Pendant
# Target Leggings
# Predicted:  Churidar
# Target Clutches
# Predicted:  Clutches
# Target Sweatshirts
# Predicted:  Sweatshirts
# Target Jackets
# Predicted:  Jackets
# Target Travel Accessory
# Predicted:  Messenger Bag
# Target Ties
# Predicted:  Ties
# Target Bra
# Predicted:  Bra
# Target Caps
# Predicted:  Shorts
# Target Bra
# Predicted:  Bra
# Target Jackets
# Predicted:  Tunics
# Target Trousers
# Predicted:  Trousers
# Target Accessory Gift Set
# Predicted:  Accessory Gift Set
# Target Backpacks
# Predicted:  Backpacks
# Target Trousers
# Predicted:  Trousers
# Target Bracelet
# Predicted:  Bracelet
# Target Sweatshirts
# Predicted:  Sweatshirts
# Target Tunics
# Predicted:  Tunics
# Target Kurtis
# Predicted:  Kurtis
# Target Bra
# Predicted:  Bra
# Target Pendant
# Predicted:  Pendant
# Target Leggings
# Predicted:  Leggings
# Target Jackets
# Predicted:  Sweatshirts
# Target Sweatshirts
# Predicted:  Sweatshirts
# Target Trousers
# Predicted:  Trousers
# Target Sweaters
# Predicted:  Sweaters
# Target Jeans
# Predicted:  Jeans
# Target Capris
# Predicted:  Shorts
# Target Backpacks
# Predicted:  Backpacks
# Target Backpacks
# Predicted:  Backpacks
# Target Pendant
# Predicted:  Pendant
# Target Jeans
# Predicted:  Jeans
# Target Bra
# Predicted:  Bra
# Target Mufflers
# Predicted:  Scarves
# Target Backpacks
# Predicted:  Backpacks
# Target Jeans
# Predicted:  Jeans
# Target Mufflers
# Predicted:  Scarves
# Target Nightdress
# Predicted:  Nightdress
# Target Jeans
# Predicted:  Capris
# Target Ring
# Predicted:  Ring
# Target Scarves
# Predicted:  Scarves
# Target Trousers
# Predicted:  Trousers
# Target Bra
# Predicted:  Bra
# Target Jeans
# Predicted:  Jeans
# Target Jackets
# Predicted:  Jackets
# Target Track Pants
# Predicted:  Track Pants
# Target Kurtis
# Predicted:  Tunics
# Target Ring
# Predicted:  Ring
# Target Trousers
# Predicted:  Jeans
# Target Bra
# Predicted:  Bra
# Target Earrings
# Predicted:  Earrings
# Target Sweatshirts
# Predicted:  Sweatshirts
# Target Capris
# Predicted:  Capris
# Target Backpacks
# Predicted:  Backpacks
# Target Jeans
# Predicted:  Jeans
# Target Clutches
# Predicted:  Clutches
# Target Duffel Bag
# Predicted:  Duffel Bag
# Target Backpacks
# Predicted:  Backpacks
# Target Backpacks
# Predicted:  Backpacks
# Target Skirts
# Predicted:  Shorts
# Target Caps
# Predicted:  Caps
# Target Jeans
# Predicted:  Jeggings
# Target Sweatshirts
# Predicted:  Sweatshirts
# Target Bra
# Predicted:  Bra
# Target Bra
# Predicted:  Bra
# Target Duffel Bag
# Predicted:  Duffel Bag
# Target Nightdress
# Predicted:  Tunics
# Target Ties
# Predicted:  Ties
# Target Backpacks
# Predicted:  Backpacks
# Target Jackets
# Predicted:  Jackets
# Target Ring
# Predicted:  Ring
# Target Kurta Sets
# Predicted:  Kurta Sets
# Target Kurta Sets
# Predicted:  Kurta Sets
# Target Robe
# Predicted:  Nightdress
# Target Sweaters
# Predicted:  Sweatshirts
# Target Bra
# Predicted:  Bra
# Target Backpacks
# Predicted:  Backpacks
# Target Clutches
# Predicted:  Clutches
# Target Stockings
# Predicted:  Tights
# Target Shorts
# Predicted:  Shorts
# Target Night suits
# Predicted:  Tunics
# Target Backpacks
# Predicted:  Backpacks
# Target Sweatshirts
# Predicted:  Sweatshirts
# Target Bra
# Predicted:  Bra
# Target Bra
# Predicted:  Bra
# Target Jeans
# Predicted:  Capris
# Target Backpacks
# Predicted:  Backpacks
# Target Sweatshirts
# Predicted:  Sweatshirts
# Target Shorts
# Predicted:  Mobile Pouch
# Target Track Pants
# Predicted:  Track Pants
# Target Clutches
# Predicted:  Clutches
# Target Skirts
# Predicted:  Skirts
# Target Sweatshirts
# Predicted:  Sweatshirts
# Target Jeans
# Predicted:  Jeans
# Target Capris
# Predicted:  Capris
# Target Sweatshirts
# Predicted:  Sweatshirts
# Target Jeans
# Predicted:  Jeans
# Target Bra
# Predicted:  Bra
# Target Headband
# Predicted:  Headband
# Target Scarves
# Predicted:  Scarves
# Target Ring
# Predicted:  Bangle
# Target Trousers
# Predicted:  Trousers
# Target Bra
# Predicted:  Bra
# Target Sweatshirts
# Predicted:  Sweatshirts
# Target Trousers
# Predicted:  Trousers
# Target Bra
# Predicted:  Bra
# Target Track Pants
# Predicted:  Track Pants
# Target Bra
# Predicted:  Bra
# Target Sweaters
# Predicted:  Sweatshirts
# Target Trousers
# Predicted:  Trousers
# Target Caps
# Predicted:  Caps
# Target Nightdress
# Predicted:  Nightdress
# Target Trousers
# Predicted:  Trousers
# Target Sports Sandals
# Predicted:  Ipad
# Target Kurta Sets
# Predicted:  Kurta Sets
# Target Earrings
# Predicted:  Earrings
# Target Bra
# Predicted:  Bra
# Target Jumpsuit
# Predicted:  Salwar and Dupatta
# Target Tunics
# Predicted:  Kurtis
# Target Capris
# Predicted:  Track Pants
# Target Bra
# Predicted:  Bra
# Target Caps
# Predicted:  Clutches
# Target Tracksuits
# Predicted:  Tracksuits
# Target Clutches
# Predicted:  Clutches
# Target Trousers
# Predicted:  Trousers
# Target Track Pants
# Predicted:  Capris
# Target Nightdress
# Predicted:  Tunics
# Target Backpacks
# Predicted:  Backpacks
# Target Shorts
# Predicted:  Shorts
# Target Sweaters
# Predicted:  Sweaters
# Target Bra
# Predicted:  Bra
# Target Bra
# Predicted:  Bra
# Target Shorts
# Predicted:  Capris
# Target Clutches
# Predicted:  Clutches
# Target Sports Sandals
# Predicted:  Sports Sandals
# Target Bra
# Predicted:  Bra
# Target Kurta Sets
# Predicted:  Kurta Sets
# Target Shorts
# Predicted:  Shorts
# Target Trousers
# Predicted:  Trousers
# Target Accessory Gift Set
# Predicted:  Accessory Gift Set
# Target Tunics
# Predicted:  Tunics
# Target Shorts
# Predicted:  Shorts
# Target Ring
# Predicted:  Ring
# Target Jeans
# Predicted:  Jeggings
# Target Sweaters
# Predicted:  Sweaters
# Target Clutches
# Predicted:  Clutches
# Target Jackets
# Predicted:  Blazers
# Target Backpacks
# Predicted:  Backpacks
# Target Lounge Pants
# Predicted:  Lounge Pants
# Target Backpacks
# Predicted:  Backpacks
# Target Trousers
# Predicted:  Jeans
# Target Ring
# Predicted:  Ring
# Target Earrings
# Predicted:  Earrings
# Target Track Pants
# Predicted:  Leggings
# Target Lounge Pants
# Predicted:  Capris
# Target Backpacks
# Predicted:  Backpacks
# Target Bra
# Predicted:  Bra
# Target Kurta Sets
# Predicted:  Kurta Sets
# Target Backpacks
# Predicted:  Backpacks
# Target Kurtis
# Predicted:  Tunics
# Target Backpacks
# Predicted:  Backpacks
# Target Bra
# Predicted:  Bra
# Target Bra
# Predicted:  Bra
# Target Kurtis
# Predicted:  Kurtis
# Target Sweaters
# Predicted:  Sweatshirts
# Target Backpacks
# Predicted:  Backpacks
# Target Shorts
# Predicted:  Shorts
# Target Sweatshirts
# Predicted:  Sweatshirts
# Target Track Pants
# Predicted:  Shorts
# Target Trousers
# Predicted:  Trousers
# Target Nightdress
# Predicted:  Jumpsuit
# Target Shorts
# Predicted:  Shorts
# Target Shorts
# Predicted:  Lounge Shorts
# Target Trousers
# Predicted:  Jeans
# Target Mobile Pouch
# Predicted:  Clutches
# Target Bra
# Predicted:  Bra
# Target Messenger Bag
# Predicted:  Backpacks
# Target Trousers
# Predicted:  Trousers
# Target Backpacks
# Predicted:  Backpacks
# Target Backpacks
# Predicted:  Backpacks
# Target Jeans
# Predicted:  Jeans
# Target Free Gifts
# Predicted:  Makeup Remover
# Target Ring
# Predicted:  Ring
# Target Earrings
# Predicted:  Earrings
# Target Lounge Pants
# Predicted:  Track Pants
# Target Track Pants
# Predicted:  Track Pants
# Target Sweatshirts
# Predicted:  Sweatshirts
# Target Nightdress
# Predicted:  Nightdress
# Target Tights
# Predicted:  Tights
# Target Clutches
# Predicted:  Clutches
# Target Bra
# Predicted:  Bra
# Target Bra
# Predicted:  Bra
# Target Sports Sandals
# Predicted:  Bangle
# Target Sweatshirts
# Predicted:  Sweatshirts
# Target Trousers
# Predicted:  Trousers
# Target Caps
# Predicted:  Caps
# Target Shorts
# Predicted:  Shorts
# Target Laptop Bag
# Predicted:  Duffel Bag
# Target Backpacks
# Predicted:  Backpacks
# Target Trousers
# Predicted:  Trousers
# Target Trousers
# Predicted:  Trousers
# Target Sweaters
# Predicted:  Sweaters
# Target Bracelet
# Predicted:  Cufflinks
# Target Jackets
# Predicted:  Jackets
# Target Clutches
# Predicted:  Laptop Bag
# Target Bra
# Predicted:  Bra
# Target Ties
# Predicted:  Ties
# Target Pendant
# Predicted:  Ring
# Target Backpacks
# Predicted:  Backpacks
# Target Bra
# Predicted:  Bra
# Target Messenger Bag
# Predicted:  Messenger Bag
# Target Jeans
# Predicted:  Jeans
# Target Sweaters
# Predicted:  Sweaters
# Target Capris
# Predicted:  Capris
# Target Backpacks
# Predicted:  Backpacks
# Target Track Pants
# Predicted:  Track Pants
# Target Jeans
# Predicted:  Jeans
# Target Jeans
# Predicted:  Jeans
# Target Nightdress
# Predicted:  Camisoles
# Target Bra
# Predicted:  Bra
# Target Pendant
# Predicted:  Pendant
# Target Caps
# Predicted:  Caps
# Target Track Pants
# Predicted:  Track Pants
# Target Mufflers
# Predicted:  Scarves
# Target Trousers
# Predicted:  Track Pants
# Target Shorts
# Predicted:  Shorts
# Target Trousers
# Predicted:  Trousers
# Target Backpacks
# Predicted:  Messenger Bag
# Target Camisoles
# Predicted:  Bra
# Target Trousers
# Predicted:  Track Pants
# Target Bangle
# Predicted:  Bracelet
# Target Caps
# Predicted:  Caps
# Target Trousers
# Predicted:  Trousers
# Target Travel Accessory
# Predicted:  Travel Accessory
# Target Backpacks
# Predicted:  Messenger Bag
# Target Sweatshirts
# Predicted:  Sweatshirts
# Target Nightdress
# Predicted:  Kurta Sets
# Target Trousers
# Predicted:  Trousers
# Target Bra
# Predicted:  Bra
# Target Jackets
# Predicted:  Blazers
# Target Leggings
# Predicted:  Leggings
# Target Bra
# Predicted:  Bra
# Target Jackets
# Predicted:  Sweatshirts
# Target Sports Sandals
# Predicted:  Sports Sandals
# Target Leggings
# Predicted:  Churidar
# Target Sweatshirts
# Predicted:  Sweaters
# Target Caps
# Predicted:  Caps
# Target Sweaters
# Predicted:  Sweaters
# Target Laptop Bag
# Predicted:  Messenger Bag
# Target Pendant
# Predicted:  Pendant
# Target Sweatshirts
# Predicted:  Sweatshirts
# Target Tunics
# Predicted:  Innerwear Vests
# Target Caps
# Predicted:  Caps
# Target Nightdress
# Predicted:  Nightdress
# Target Shorts
# Predicted:  Shorts
# Target Jackets
# Predicted:  Waistcoat
# Target Sweaters
# Predicted:  Sweaters
# Target Lounge Pants
# Predicted:  Capris
# Target Shorts
# Predicted:  Shorts
# Target Duffel Bag
# Predicted:  Backpacks
# Target Bra
# Predicted:  Bra
# Target Messenger Bag
# Predicted:  Messenger Bag
# Target Jeans
# Predicted:  Jeans
# Target Backpacks
# Predicted:  Backpacks
# Target Clutches
# Predicted:  Clutches
# Target Track Pants
# Predicted:  Track Pants
# Target Jeans
# Predicted:  Jeans
# Target Shoe Accessories
# Predicted:  Cufflinks
# Target Trousers
# Predicted:  Track Pants
# Target Stockings
# Predicted:  Tights
# Target Gloves
# Predicted:  Gloves
# Target Jeans
# Predicted:  Jeans
# Target Sports Sandals
# Predicted:  Sports Sandals
# Target Pendant
# Predicted:  Pendant
# Target Jeans
# Predicted:  Jeans
# Target Backpacks
# Predicted:  Backpacks
# Target Capris
# Predicted:  Capris
# Target Jeans
# Predicted:  Jeans
# Target Night suits
# Predicted:  Kurta Sets
# Target Bra
# Predicted:  Bra
# Target Tunics
# Predicted:  Tunics
# Target Leggings
# Predicted:  Leggings
# Target Bra
# Predicted:  Bra
# Target Capris
# Predicted:  Capris
# Target Ties
# Predicted:  Ties
# Target Backpacks
# Predicted:  Messenger Bag
# Target Kurtis
# Predicted:  Tunics
# Target Sweatshirts
# Predicted:  Sweatshirts
# Target Backpacks
# Predicted:  Backpacks
# Target Lounge Shorts
# Predicted:  Capris
# Target Caps
# Predicted:  Caps
# Target Pendant
# Predicted:  Free Gifts
# Target Backpacks
# Predicted:  Backpacks
# Target Sweatshirts
# Predicted:  Nehru Jackets
# Target Clutches
# Predicted:  Clutches
# Target Accessory Gift Set
# Predicted:  Accessory Gift Set
# Target Track Pants
# Predicted:  Track Pants
# Target Mufflers
# Predicted:  Scarves
# Target Tunics
# Predicted:  Kurtis
# Target Tunics
# Predicted:  Kurtis
# Target Caps
# Predicted:  Caps
# Target Shoe Accessories
# Predicted:  Makeup Remover
# Target Caps
# Predicted:  Caps
# Target Bra
# Predicted:  Bra
# Target Night suits
# Predicted:  Night suits
# Target Sweatshirts
# Predicted:  Sweatshirts
# Target Clutches
# Predicted:  Clutches
# Target Clutches
# Predicted:  Clutches
# Target Shoe Accessories
# Predicted:  Clutches
# Target Waistcoat
# Predicted:  Nehru Jackets
# Target Pendant
# Predicted:  Pendant
# Target Caps
# Predicted:  Caps
# Target Bra
# Predicted:  Bra
# Target Mufflers
# Predicted:  Scarves
# Target Backpacks
# Predicted:  Backpacks
# Target Night suits
# Predicted:  Lounge Tshirts
# Target Sweatshirts
# Predicted:  Jackets
# Target Capris
# Predicted:  Capris
# Target Backpacks
# Predicted:  Backpacks
# Target Track Pants
# Predicted:  Lounge Pants
# Target Lounge Pants
# Predicted:  Lounge Pants
# Target Pendant
# Predicted:  Pendant
# Target Shorts
# Predicted:  Shorts
# Target Scarves
# Predicted:  Leggings
# Target Track Pants
# Predicted:  Track Pants
# Target Caps
# Predicted:  Caps
# Target Shorts
# Predicted:  Shorts
# Target Track Pants
# Predicted:  Track Pants
# Target Bra
# Predicted:  Bra
# Target Shorts
# Predicted:  Shorts
# Target Camisoles
# Predicted:  Bra
# Target Dupatta
# Predicted:  Scarves
# Target Jeans
# Predicted:  Leggings
# Target Bra
# Predicted:  Bra
# Target Trousers
# Predicted:  Trousers
# Target Trousers
# Predicted:  Trousers
# Target Nightdress
# Predicted:  Nightdress
# Target Backpacks
# Predicted:  Backpacks
# Target Track Pants
# Predicted:  Track Pants
# Target Jackets
# Predicted:  Sweatshirts
# Target Clutches
# Predicted:  Duffel Bag
# Target Sweatshirts
# Predicted:  Sweatshirts
# Target Bra
# Predicted:  Bra
# Target Shorts
# Predicted:  Shorts
# Target Trousers
# Predicted:  Trousers
# Target Mobile Pouch
# Predicted:  Mobile Pouch
# Target Skirts
# Predicted:  Clothing Set
# Target Wristbands
# Predicted:  Wristbands
# Target Bra
# Predicted:  Bra
# Target Kurtis
# Predicted:  Tunics
# Target Backpacks
# Predicted:  Backpacks
# Target Bra
# Predicted:  Bra
# Target Duffel Bag
# Predicted:  Duffel Bag
# Target Lounge Pants
# Predicted:  Track Pants
# Target Trousers
# Predicted:  Trousers
# Target Track Pants
# Predicted:  Track Pants
# Target Ring
# Predicted:  Ring
# Target Bra
# Predicted:  Bra
# Target Nightdress
# Predicted:  Nightdress
# Target Stockings
# Predicted:  Leggings
# Target Track Pants
# Predicted:  Track Pants
# Target Backpacks
# Predicted:  Backpacks
# Target Backpacks
# Predicted:  Backpacks
# Target Kurta Sets
# Predicted:  Kurta Sets
# Target Laptop Bag
# Predicted:  Messenger Bag
# Target Travel Accessory
# Predicted:  Duffel Bag
# Target Ring
# Predicted:  Ring
# Target Skirts
# Predicted:  Skirts
# Target Earrings
# Predicted:  Earrings
# Target Jeans
# Predicted:  Jeans
# Target Trousers
# Predicted:  Trousers
# Target Sweatshirts
# Predicted:  Sweatshirts
# Target Accessory Gift Set
# Predicted:  Accessory Gift Set
# Target Shorts
# Predicted:  Shorts
# Target Caps
# Predicted:  Caps
# Target Bra
# Predicted:  Bra
# Target Jackets
# Predicted:  Jackets
# Target Earrings
# Predicted:  Earrings
# Target Ring
# Predicted:  Ring
# Target Jeans
# Predicted:  Jeans
# Target Tracksuits
# Predicted:  Tracksuits
# Target Jeans
# Predicted:  Jeans
# Target Clutches
# Predicted:  Clutches
# Target Bra
# Predicted:  Bra
# Target Jeans
# Predicted:  Trousers
# Target Bra
# Predicted:  Bra
# Target Sweaters
# Predicted:  Sweaters
# Target Shorts
# Predicted:  Shorts
# Target Clutches
# Predicted:  Clutches
# Target Shorts
# Predicted:  Capris
# Target Bra
# Predicted:  Bra
# Target Bangle
# Predicted:  Bracelet
# Target Nightdress
# Predicted:  Nightdress
# Target Backpacks
# Predicted:  Backpacks
# Target Ring
# Predicted:  Ring
# Target Trousers
# Predicted:  Trousers
# Target Track Pants
# Predicted:  Track Pants
# Target Sweaters
# Predicted:  Sweatshirts
# Target Backpacks
# Predicted:  Backpacks
# Target Kurtis
# Predicted:  Kurtis
# Target Bra
# Predicted:  Bra
# Target Backpacks
# Predicted:  Backpacks
# Target Ties
# Predicted:  Ties
# Target Sweaters
# Predicted:  Sweatshirts
# Target Jeans
# Predicted:  Jeans
# Target Ring
# Predicted:  Ring
# Target Backpacks
# Predicted:  Backpacks
# Target Lounge Pants
# Predicted:  Track Pants
# Target Clutches
# Predicted:  Clutches
# Target Swimwear
# Predicted:  Camisoles
# Target Sweatshirts
# Predicted:  Sweatshirts
# Target Sweatshirts
# Predicted:  Sweatshirts
# Target Trousers
# Predicted:  Trousers
# Target Backpacks
# Predicted:  Backpacks
# Target Skirts
# Predicted:  Skirts
# Target Bra
# Predicted:  Bra
# Target Headband
# Predicted:  Headband
# Target Ring
# Predicted:  Bangle
# Target Scarves
# Predicted:  Scarves
# Target Bra
# Predicted:  Bra
# Target Trousers
# Predicted:  Trousers
# Target Jeans
# Predicted:  Jeans
# Target Sweaters
# Predicted:  Sweatshirts
# Target Bra
# Predicted:  Bra
# Target Bra
# Predicted:  Bra
# Target Sweatshirts
# Predicted:  Sweatshirts
# Target Stockings
# Predicted:  Stockings
# Target Night suits
# Predicted:  Tunics
# Target Shorts
# Predicted:  Shorts
# Target Backpacks
# Predicted:  Backpacks
# Target Shorts
# Predicted:  Shorts
# Target Jeans
# Predicted:  Jeans
# Target Clutches
# Predicted:  Clutches
# Target Backpacks
# Predicted:  Backpacks
# Target Backpacks
# Predicted:  Backpacks
# Target Footballs
# Predicted:  Footballs
# Target Shorts
# Predicted:  Pendant
# Target Kurtis
# Predicted:  Kurtis
# Target Jumpsuit
# Predicted:  Jumpsuit
# Target Caps
# Predicted:  Caps
# Target Bra
# Predicted:  Bra
# Target Bra
# Predicted:  Bra
# Target Trousers
# Predicted:  Track Pants
# Target Trousers
# Predicted:  Trousers
# Target Sweaters
# Predicted:  Sweaters
# Target Nightdress
# Predicted:  Nightdress
# Target Bra
# Predicted:  Bra
# Target Backpacks
# Predicted:  Backpacks
# Target Skirts
# Predicted:  Skirts
# Target Clutches
# Predicted:  Clutches
# Target Trousers
# Predicted:  Trousers
# Target Jeans
# Predicted:  Jeans
# Target Backpacks
# Predicted:  Backpacks
# Target Track Pants
# Predicted:  Track Pants
# Target Nightdress
# Predicted:  Nightdress
# Target Backpacks
# Predicted:  Backpacks
# Target Jeans
# Predicted:  Jeans
# Target Bra
# Predicted:  Bra
# Target Bra
# Predicted:  Bra
# Target Sweatshirts
# Predicted:  Sweatshirts
# Target Jeans
# Predicted:  Trousers
# Target Track Pants
# Predicted:  Track Pants
# Target Jackets
# Predicted:  Jackets
# Target Kurtis
# Predicted:  Tunics
# Target Scarves
# Predicted:  Mufflers
# Target Bra
# Predicted:  Bra
# Target Trousers
# Predicted:  Trousers
# Target Lounge Pants
# Predicted:  Capris
# Target Duffel Bag
# Predicted:  Duffel Bag
# Target Jeans
# Predicted:  Jeans
# Target Bra
# Predicted:  Bra
# Target Ring
# Predicted:  Ring
# Target Trousers
# Predicted:  Trousers
# Target Sweatshirts
# Predicted:  Sweatshirts
# Target Track Pants
# Predicted:  Leggings
# Target Bra
# Predicted:  Bra
# Target Sweaters
# Predicted:  Sweaters
# Target Tracksuits
# Predicted:  Tracksuits
# Target Backpacks
# Predicted:  Backpacks
# Target Clutches
# Predicted:  Clutches
# Target Earrings
# Predicted:  Earrings
# Target Ring
# Predicted:  Ring
# Target Mufflers
# Predicted:  Scarves
# Target Nightdress
# Predicted:  Nightdress
# Target Kurta Sets
# Predicted:  Kurta Sets
# Target Kurta Sets
# Predicted:  Kurta Sets
# Target Bra
# Predicted:  Bra
# Target Backpacks
# Predicted:  Backpacks
# Target Earrings
# Predicted:  Earrings
# Target Earrings
# Predicted:  Earrings
# Target Leggings
# Predicted:  Track Pants
# Target Jackets
# Predicted:  Sweatshirts
# Target Track Pants
# Predicted:  Track Pants
# Target Track Pants
# Predicted:  Track Pants
# Target Bra
# Predicted:  Bra
# Target Shorts
# Predicted:  Shorts
# Target Jeans
# Predicted:  Jeans
# Target Kurtis
# Predicted:  Kurtis
# Target Backpacks
# Predicted:  Backpacks
# Target Backpacks
# Predicted:  Backpacks
# Target Backpacks
# Predicted:  Backpacks
# Target Duffel Bag
# Predicted:  Duffel Bag
# Target Backpacks
# Predicted:  Backpacks
# Target Free Gifts
# Predicted:  Free Gifts
# Target Trousers
# Predicted:  Trousers
# Target Necklace and Chains
# Predicted:  Necklace and Chains
# Target Bra
# Predicted:  Bra
# Target Cufflinks
# Predicted:  Cufflinks
# Target Capris
# Predicted:  Capris
# Target Backpacks
# Predicted:  Backpacks
# Target Accessory Gift Set
# Predicted:  Accessory Gift Set
# Target Skirts
# Predicted:  Skirts
# Target Bra
# Predicted:  Bra
# Target Tunics
# Predicted:  Tunics
# Target Shorts
# Predicted:  Lounge Shorts
# Target Shorts
# Predicted:  Shorts
# Target Bra
# Predicted:  Bra
# Target Track Pants
# Predicted:  Track Pants
# Target Sweaters
# Predicted:  Sweatshirts
# Target Track Pants
# Predicted:  Track Pants
# Target Accessory Gift Set
# Predicted:  Accessory Gift Set
# Target Skirts
# Predicted:  Nightdress
# Target Earrings
# Predicted:  Earrings
# Target Duffel Bag
# Predicted:  Messenger Bag
# Target Trousers
# Predicted:  Trousers
# Target Mufflers
# Predicted:  Mufflers
# Target Necklace and Chains
# Predicted:  Necklace and Chains
# Target Trousers
# Predicted:  Trousers
# Target Bra
# Predicted:  Bra
# Target Jackets
# Predicted:  Sweatshirts
# Target Tunics
# Predicted:  Tunics
# Target Cufflinks
# Predicted:  Cufflinks
# Target Backpacks
# Predicted:  Backpacks
# Target Jewellery Set
# Predicted:  Jewellery Set
# Target Pendant
# Predicted:  Pendant
# Target Duffel Bag
# Predicted:  Duffel Bag
# Target Bra
# Predicted:  Bra
# Target Duffel Bag
# Predicted:  Duffel Bag
# Target Kurtis
# Predicted:  Kurtis
# Target Laptop Bag
# Predicted:  Messenger Bag
# Target Tracksuits
# Predicted:  Tracksuits
# Target Ties
# Predicted:  Ties
# Target Skirts
# Predicted:  Skirts
# Target Mobile Pouch
# Predicted:  Mobile Pouch
# Target Backpacks
# Predicted:  Backpacks
# Target Sweatshirts
# Predicted:  Sweatshirts
# Target Track Pants
# Predicted:  Track Pants
# Target Sweaters
# Predicted:  Sweaters
# Target Backpacks
# Predicted:  Backpacks
# Target Bra
# Predicted:  Bra
# Target Backpacks
# Predicted:  Backpacks
# Target Jackets
# Predicted:  Innerwear Vests
# Target Ties
# Predicted:  Ties
# Target Backpacks
# Predicted:  Backpacks
# Target Pendant
# Predicted:  Pendant
# Target Travel Accessory
# Predicted:  Messenger Bag
# Target Caps
# Predicted:  Caps
# Target Jeans
# Predicted:  Jeans
# Target Bra
# Predicted:  Bra
# Target Necklace and Chains
# Predicted:  Necklace and Chains
# Target Trousers
# Predicted:  Trousers
# Target Caps
# Predicted:  Caps
# Target Sweaters
# Predicted:  Sweatshirts
# Target Sweaters
# Predicted:  Innerwear Vests
# Target Bra
# Predicted:  Bra
# Target Laptop Bag
# Predicted:  Duffel Bag
# Target Accessory Gift Set
# Predicted:  Accessory Gift Set
# Target Backpacks
# Predicted:  Backpacks
# Target Backpacks
# Predicted:  Backpacks
# Target Camisoles
# Predicted:  Clothing Set
# Target Backpacks
# Predicted:  Backpacks
# Target Jackets
# Predicted:  Blazers
# Target Accessory Gift Set
# Predicted:  Accessory Gift Set
# Target Jeans
# Predicted:  Jeans
# Target Laptop Bag
# Predicted:  Messenger Bag
# Target Bra
# Predicted:  Bra
# Target Capris
# Predicted:  Capris
# Target Pendant
# Predicted:  Pendant
# Target Backpacks
# Predicted:  Backpacks
# Target Caps
# Predicted:  Caps
# Target Earrings
# Predicted:  Earrings
# Target Sweaters
# Predicted:  Sweatshirts
# Target Ties
# Predicted:  Ties
# Target Sweatshirts
# Predicted:  Sweatshirts
# Target Backpacks
# Predicted:  Backpacks
# Target Ties
# Predicted:  Ties
# Target Sweatshirts
# Predicted:  Sweatshirts
# Target Laptop Bag
# Predicted:  Laptop Bag
# Target Jackets
# Predicted:  Jackets
# Target Backpacks
# Predicted:  Backpacks
# Target Scarves
# Predicted:  Mufflers
# Target Jeans
# Predicted:  Leggings
# Target Duffel Bag
# Predicted:  Duffel Bag
# Target Caps
# Predicted:  Caps
# Target Bra
# Predicted:  Bra
# Target Shorts
# Predicted:  Shorts
# Target Track Pants
# Predicted:  Track Pants
# Target Backpacks
# Predicted:  Backpacks
# Target Accessory Gift Set
# Predicted:  Accessory Gift Set
# Target Skirts
# Predicted:  Nightdress
# Target Backpacks
# Predicted:  Backpacks
# Target Bra
# Predicted:  Bra
# Target Messenger Bag
# Predicted:  Messenger Bag
# Target Laptop Bag
# Predicted:  Duffel Bag
# Target Mufflers
# Predicted:  Mufflers
# Target Accessory Gift Set
# Predicted:  Accessory Gift Set
# Target Trousers
# Predicted:  Trousers
# Target Backpacks
# Predicted:  Backpacks
# Target Bra
# Predicted:  Bra
# Target Sweaters
# Predicted:  Sweaters
# Target Trousers
# Predicted:  Trousers
# Target Shorts
# Predicted:  Shorts
# Target Sweaters
# Predicted:  Sweatshirts
# Target Night suits
# Predicted:  Kurta Sets
# Target Sweaters
# Predicted:  Sweaters
# Target Backpacks
# Predicted:  Rucksacks
# Target Tunics
# Predicted:  Kurtis
# Target Accessory Gift Set
# Predicted:  Accessory Gift Set
# Target Backpacks
# Predicted:  Backpacks
# Target Jackets
# Predicted:  Sweatshirts
# Target Leggings
# Predicted:  Leggings
# Target Scarves
# Predicted:  Stoles
# Target Nightdress
# Predicted:  Tunics
# Target Shorts
# Predicted:  Capris
# Target Sweatshirts
# Predicted:  Sweatshirts
# Target Night suits
# Predicted:  Kurta Sets
# Target Jeans
# Predicted:  Jeans
# Target Sweatshirts
# Predicted:  Sweatshirts
# Target Backpacks
# Predicted:  Backpacks
# Target Track Pants
# Predicted:  Track Pants
# Target Sweatshirts
# Predicted:  Sweatshirts
# Target Sweatshirts
# Predicted:  Sweatshirts
# Target Track Pants
# Predicted:  Track Pants
# Target Earrings
# Predicted:  Earrings
# Target Laptop Bag
# Predicted:  Clutches
# Target Jackets
# Predicted:  Jackets
# Target Jeans
# Predicted:  Jeans
# Target Shorts
# Predicted:  Kurta Sets
# Target Backpacks
# Predicted:  Backpacks
# Target Bracelet
# Predicted:  Bracelet
# Target Nightdress
# Predicted:  Tunics
# Target Trousers
# Predicted:  Trousers
# Target Backpacks
# Predicted:  Backpacks
# Target Sweatshirts
# Predicted:  Sweatshirts
# Target Jeans
# Predicted:  Jeans
# Target Skirts
# Predicted:  Skirts
# Target Nightdress
# Predicted:  Kurta Sets
# Target Night suits
# Predicted:  Kurta Sets
# Target Backpacks
# Predicted:  Backpacks
# Target Nightdress
# Predicted:  Tunics
# Target Shorts
# Predicted:  Shorts
# Target Trousers
# Predicted:  Trousers
# Target Backpacks
# Predicted:  Backpacks
# Target Shorts
# Predicted:  Shorts
# Target Tracksuits
# Predicted:  Tracksuits
# Target Kurtis
# Predicted:  Kurtis
# Target Waist Pouch
# Predicted:  Messenger Bag
# Target Trousers
# Predicted:  Trousers
# Target Caps
# Predicted:  Caps
# Target Night suits
# Predicted:  Salwar and Dupatta
# Target Jackets
# Predicted:  Jackets
# Target Jeans
# Predicted:  Jeans
# Target Camisoles
# Predicted:  Camisoles
# Target Track Pants
# Predicted:  Track Pants
# Target Trousers
# Predicted:  Trousers
# Target Sweaters
# Predicted:  Sweaters
# Target Sweaters
# Predicted:  Jackets
# Target Jeans
# Predicted:  Jeans
# Target Shorts
# Predicted:  Shorts
# Target Earrings
# Predicted:  Earrings
# Target Sweatshirts
# Predicted:  Sweatshirts
# Target Backpacks
# Predicted:  Backpacks
# Target Sweatshirts
# Predicted:  Jackets
# Target Track Pants
# Predicted:  Track Pants
# Target Backpacks
# Predicted:  Backpacks
# Target Earrings
# Predicted:  Earrings
# Target Jewellery Set
# Predicted:  Jewellery Set
# Target Necklace and Chains
# Predicted:  Necklace and Chains
# Target Trousers
# Predicted:  Trousers
# Target Bra
# Predicted:  Bra
# Target Jackets
# Predicted:  Jackets
# Target Nightdress
# Predicted:  Tunics
# Target Tracksuits
# Predicted:  Tracksuits
# Target Scarves
# Predicted:  Scarves
# Target Jeans
# Predicted:  Jeans
# Target Duffel Bag
# Predicted:  Duffel Bag
# Target Caps
# Predicted:  Caps
# Target Jeans
# Predicted:  Jeans
# Target Necklace and Chains
# Predicted:  Necklace and Chains
# Target Pendant
# Predicted:  Pendant
# Target Caps
# Predicted:  Caps
# Target Sports Sandals
# Predicted:  Sports Sandals
# Target Sweaters
# Predicted:  Sweaters
# Target Trousers
# Predicted:  Trousers
# Target Caps
# Predicted:  Caps
# Target Shorts
# Predicted:  Lounge Shorts
# Target Nightdress
# Predicted:  Nightdress
# Target Sweatshirts
# Predicted:  Sweatshirts
# Target Shorts
# Predicted:  Shorts
# Target Clutches
# Predicted:  Clutches
# Target Shorts
# Predicted:  Shorts
# Target Earrings
# Predicted:  Earrings
# Target Laptop Bag
# Predicted:  Clutches
# Target Mobile Pouch
# Predicted:  Laptop Bag
# Target Bra
# Predicted:  Bra
# Target Jeans
# Predicted:  Jeans
# Target Night suits
# Predicted:  Kurta Sets
# Target Jeans
# Predicted:  Jeans
# Target Messenger Bag
# Predicted:  Messenger Bag
# Target Shorts
# Predicted:  Track Pants
# Target Robe
# Predicted:  Nightdress
# Target Kurtis
# Predicted:  Kurtis
# Target Stoles
# Predicted:  Scarves
# Target Nightdress
# Predicted:  Nightdress
# Target Caps
# Predicted:  Caps
# Target Earrings
# Predicted:  Earrings
# Target Shorts
# Predicted:  Shorts
# Target Skirts
# Predicted:  Skirts
# Target Shorts
# Predicted:  Shorts
# Target Jeans
# Predicted:  Jeans
# Target Jackets
# Predicted:  Jackets
# Target Leggings
# Predicted:  Churidar
# Target Nightdress
# Predicted:  Nightdress
# Target Bra
# Predicted:  Bra
# Target Trousers
# Predicted:  Trousers
# Target Clutches
# Predicted:  Clutches
# Target Sweaters
# Predicted:  Sweaters
# Target Jackets
# Predicted:  Jackets
# Target Trousers
# Predicted:  Trousers
# Target Sweaters
# Predicted:  Kurtis
# Target Sweatshirts
# Predicted:  Sweatshirts
# Target Sweatshirts
# Predicted:  Sweatshirts
# Target Necklace and Chains
# Predicted:  Necklace and Chains
# Target Track Pants
# Predicted:  Track Pants
# Target Jackets
# Predicted:  Rain Jacket
# Target Trousers
# Predicted:  Trousers
# Target Scarves
# Predicted:  Scarves
# Target Jeans
# Predicted:  Jeans
# Target Nightdress
# Predicted:  Tunics
# Target Caps
# Predicted:  Caps
# Target Jackets
# Predicted:  Jackets
# Target Jeans
# Predicted:  Jeans
# Target Jackets
# Predicted:  Sweatshirts
# Target Shorts
# Predicted:  Shorts
# Target Jeans
# Predicted:  Jeans
# Target Backpacks
# Predicted:  Backpacks
# Target Nightdress
# Predicted:  Nightdress
# Target Ties
# Predicted:  Ties
# Target Sweatshirts
# Predicted:  Sweatshirts
# Target Trousers
# Predicted:  Trousers
# Target Trousers
# Predicted:  Trousers
# Target Laptop Bag
# Predicted:  Duffel Bag
# Target Sweatshirts
# Predicted:  Sweatshirts
# Target Backpacks
# Predicted:  Backpacks
# Target Accessory Gift Set
# Predicted:  Accessory Gift Set
# Target Sweaters
# Predicted:  Sweaters
# Target Bra
# Predicted:  Bra
# Target Pendant
# Predicted:  Pendant
# Target Backpacks
# Predicted:  Backpacks
# Target Earrings
# Predicted:  Earrings
# Target Backpacks
# Predicted:  Backpacks
# Target Ties
# Predicted:  Ties
# Target Shorts
# Predicted:  Shorts
# Target Sweatshirts
# Predicted:  Sweatshirts
# Target Trousers
# Predicted:  Trousers
# Target Earrings
# Predicted:  Earrings
# Target Accessory Gift Set
# Predicted:  Accessory Gift Set
# Target Caps
# Predicted:  Caps
# Target Caps
# Predicted:  Caps
# Target Bra
# Predicted:  Bra
# Target Sweaters
# Predicted:  Sweaters
# Target Necklace and Chains
# Predicted:  Necklace and Chains
# Target Trousers
# Predicted:  Trousers
# Target Trousers
# Predicted:  Trousers
# Target Cufflinks
# Predicted:  Cufflinks
# Target Bra
# Predicted:  Bra
# Target Backpacks
# Predicted:  Backpacks
# Target Caps
# Predicted:  Caps
# Target Sweatshirts
# Predicted:  Sweatshirts
# Target Track Pants
# Predicted:  Track Pants
# Target Backpacks
# Predicted:  Backpacks
# Target Skirts
# Predicted:  Nightdress
# Target Sweatshirts
# Predicted:  Sweatshirts
# Target Jackets
# Predicted:  Jackets
# Target Accessory Gift Set
# Predicted:  Accessory Gift Set
# Target Track Pants
# Predicted:  Track Pants
# Target Jewellery Set
# Predicted:  Jewellery Set
# Target Ties
# Predicted:  Ties
# Target Backpacks
# Predicted:  Backpacks
# Target Backpacks
# Predicted:  Backpacks
# Target Backpacks
# Predicted:  Backpacks
# Target Jackets
# Predicted:  Backpacks
# Target Pendant
# Predicted:  Pendant
# Target Caps
# Predicted:  Bangle
# Target Backpacks
# Predicted:  Messenger Bag
# Target Backpacks
# Predicted:  Backpacks
# Target Sweatshirts
# Predicted:  Sweatshirts
# Target Ties
# Predicted:  Ties
# Target Bra
# Predicted:  Bra
# Target Jeans
# Predicted:  Jeans
# Target Duffel Bag
# Predicted:  Duffel Bag
# Target Sweaters
# Predicted:  Sweaters
# Target Accessory Gift Set
# Predicted:  Accessory Gift Set
# Target Backpacks
# Predicted:  Backpacks
# Target Jackets
# Predicted:  Jackets
# Target Jackets
# Predicted:  Jackets
# Target Backpacks
# Predicted:  Backpacks
# Target Bra
# Predicted:  Bra
# Target Pendant
# Predicted:  Pendant
# Target Sweaters
# Predicted:  Sweaters
# Target Backpacks
# Predicted:  Backpacks
# Target Sweatshirts
# Predicted:  Sweatshirts
# Target Bra
# Predicted:  Bra
# Target Trousers
# Predicted:  Trousers
# Target Necklace and Chains
# Predicted:  Necklace and Chains
# Target Jeans
# Predicted:  Jeans
# Target Messenger Bag
# Predicted:  Messenger Bag
# Target Camisoles
# Predicted:  Tablet Sleeve
# Target Caps
# Predicted:  Caps
# Target Laptop Bag
# Predicted:  Laptop Bag
# Target Accessory Gift Set
# Predicted:  Accessory Gift Set
# Target Laptop Bag
# Predicted:  Duffel Bag
# Target Skirts
# Predicted:  Nightdress
# Target Earrings
# Predicted:  Earrings
# Target Accessory Gift Set
# Predicted:  Accessory Gift Set
# Target Track Pants
# Predicted:  Track Pants
# Target Sweatshirts
# Predicted:  Sweatshirts
# Target Track Pants
# Predicted:  Track Pants
# Target Shorts
# Predicted:  Shorts
# Target Tunics
# Predicted:  Tunics
# Target Sweatshirts
# Predicted:  Sweatshirts
# Target Caps
# Predicted:  Caps
# Target Caps
# Predicted:  Caps
# Target Bra
# Predicted:  Bra
# Target Caps
# Predicted:  Caps
# Target Ties
# Predicted:  Ties
# Target Rucksacks
# Predicted:  Rucksacks
# Target Backpacks
# Predicted:  Backpacks
# Target Pendant
# Predicted:  Pendant
# Target Sweaters
# Predicted:  Nehru Jackets
# Target Duffel Bag
# Predicted:  Duffel Bag
# Target Kurtis
# Predicted:  Kurtis
# Target Skirts
# Predicted:  Skirts
# Target Trousers
# Predicted:  Trousers
# Target Accessory Gift Set
# Predicted:  Accessory Gift Set
# Target Trousers
# Predicted:  Trousers
# Target Mufflers
# Predicted:  Scarves
# Target Track Pants
# Predicted:  Night suits
# Target Trousers
# Predicted:  Trousers
# Target Bra
# Predicted:  Bra
# Target Jackets
# Predicted:  Sweatshirts
# Target Cufflinks
# Predicted:  Cufflinks
# Target Sweatshirts
# Predicted:  Sweaters
# Target Bra
# Predicted:  Bra
# Target Sweaters
# Predicted:  Sweatshirts
# Target Backpacks
# Predicted:  Backpacks
# Target Leggings
# Predicted:  Leggings
# Target Tracksuits
# Predicted:  Tracksuits
# Target Necklace and Chains
# Predicted:  Necklace and Chains
# Target Trousers
# Predicted:  Trousers
# Target Bra
# Predicted:  Bra
# Target Kurta Sets
# Predicted:  Kurta Sets
# Target Cufflinks
# Predicted:  Cufflinks
# Target Kurtis
# Predicted:  Kurtis
# Target Backpacks
# Predicted:  Backpacks
# Target Accessory Gift Set
# Predicted:  Accessory Gift Set
# Target Backpacks
# Predicted:  Backpacks
# Target Trousers
# Predicted:  Trousers
# Target Sports Sandals
# Predicted:  Sports Sandals
# Target Sweatshirts
# Predicted:  Sweatshirts
# Target Jeans
# Predicted:  Jeans
# Target Kurtis
# Predicted:  Kurtis
# Target Laptop Bag
# Predicted:  Messenger Bag
# Target Sweatshirts
# Predicted:  Sweatshirts
# Target Backpacks
# Predicted:  Backpacks
# Target Backpacks
# Predicted:  Backpacks
# Target Backpacks
# Predicted:  Backpacks
# Target Skirts
# Predicted:  Skirts
# Target Sweatshirts
# Predicted:  Sweatshirts
# Target Sweaters
# Predicted:  Sweaters
# Target Kurtis
# Predicted:  Kurtis
# Target Trousers
# Predicted:  Trousers
# Target Sweatshirts
# Predicted:  Sweatshirts
# Target Tunics
# Predicted:  Tunics
# Target Nightdress
# Predicted:  Tunics
# Target Swimwear
# Predicted:  Swimwear
# Target Track Pants
# Predicted:  Track Pants
# Target Jeans
# Predicted:  Jeans
# Target Nightdress
# Predicted:  Tunics
# Target Sweatshirts
# Predicted:  Sweatshirts
# Target Trousers
# Predicted:  Trousers
# Target Leggings
# Predicted:  Churidar
# Target Sweatshirts
# Predicted:  Sweatshirts
# Target Jackets
# Predicted:  Jackets
# Target Sweaters
# Predicted:  Sweaters
# Target Trousers
# Predicted:  Trousers
# Target Sweaters
# Predicted:  Kurtis
# Target Backpacks
# Predicted:  Backpacks
# Target Jeans
# Predicted:  Jeans
# Target Jeans
# Predicted:  Jeans
# Target Lounge Pants
# Predicted:  Lounge Tshirts
# Target Jackets
# Predicted:  Jackets
# Target Trousers
# Predicted:  Trousers
# Target Kurtis
# Predicted:  Kurtis
# Target Sweaters
# Predicted:  Sweaters
# Target Trousers
# Predicted:  Trousers
# Target Caps
# Predicted:  Caps
# Target Backpacks
# Predicted:  Backpacks
# Target Sweatshirts
# Predicted:  Sweatshirts
# Target Earrings
# Predicted:  Earrings
# Target Shorts
# Predicted:  Shorts
# Target Backpacks
# Predicted:  Backpacks
# Target Mobile Pouch
# Predicted:  Laptop Bag
# Target Nightdress
# Predicted:  Tunics
# Target Clutches
# Predicted:  Clutches
# Target Shorts
# Predicted:  Shorts
# Target Sweatshirts
# Predicted:  Stoles
# Target Jackets
# Predicted:  Sweatshirts
# Target Scarves
# Predicted:  Scarves
# Target Nightdress
# Predicted:  Tunics
# Target Backpacks
# Predicted:  Backpacks
# Target Capris
# Predicted:  Capris
# Target Jeans
# Predicted:  Jeans
# Target Pendant
# Predicted:  Ring
# Target Duffel Bag
# Predicted:  Duffel Bag
# Target Sweaters
# Predicted:  Sweaters
# Target Shorts
# Predicted:  Capris
# Target Cufflinks
# Predicted:  Cufflinks
# Target Caps
# Predicted:  Caps
# Target Earrings
# Predicted:  Earrings
# Target Backpacks
# Predicted:  Backpacks
# Target Jackets
# Predicted:  Jackets
# Target Jeans
# Predicted:  Jeans
# Target Skirts
# Predicted:  Skirts
# Target Messenger Bag
# Predicted:  Backpacks
# Target Jeans
# Predicted:  Jeans
# Target Night suits
# Predicted:  Kurta Sets
# Target Stoles
# Predicted:  Stoles
# Target Nightdress
# Predicted:  Jumpsuit
# Target Robe
# Predicted:  Nightdress
# Target Backpacks
# Predicted:  Backpacks
# Target Tunics
# Predicted:  Kurtis
# Target Bra
# Predicted:  Bra
# Target Sweatshirts
# Predicted:  Sweatshirts
# Target Jackets
# Predicted:  Sweatshirts
# Target Backpacks
# Predicted:  Backpacks
# Target Shorts
# Predicted:  Shorts
# Target Trousers
# Predicted:  Trousers
# Target Lounge Pants
# Predicted:  Capris
# Target Jackets
# Predicted:  Jackets
# Target Night suits
# Predicted:  Kurta Sets
# Target Caps
# Predicted:  Dupatta
# Target Duffel Bag
# Predicted:  Duffel Bag
# Target Trousers
# Predicted:  Track Pants
# Target Skirts
# Predicted:  Skirts
# Target Night suits
# Predicted:  Kurta Sets
# Target Nightdress
# Predicted:  Jumpsuit
# Target Waist Pouch
# Predicted:  Clutches
# Target Sweatshirts
# Predicted:  Sweatshirts
# Target Jackets
# Predicted:  Jackets
# Target Kurtis
# Predicted:  Kurtis
# Target Trousers
# Predicted:  Jeans
# Target Kurtis
# Predicted:  Tunics
# Target Nightdress
# Predicted:  Tunics
# Target Jeans
# Predicted:  Jeans
# Target Jackets
# Predicted:  Sweaters
# Target Sweaters
# Predicted:  Jackets
# Target Trousers
# Predicted:  Trousers
# Target Laptop Bag
# Predicted:  Messenger Bag
# Target Sweatshirts
# Predicted:  Sweatshirts
# Target Backpacks
# Predicted:  Backpacks
# Target Jackets
# Predicted:  Jackets
# Target Track Pants
# Predicted:  Track Pants
# Target Bracelet
# Predicted:  Bracelet
# Target Track Pants
# Predicted:  Track Pants
# Target Stoles
# Predicted:  Stoles
# Target Nightdress
# Predicted:  Kurta Sets
# Target Nightdress
# Predicted:  Jumpsuit
# Target Leggings
# Predicted:  Jeans
# Target Sweatshirts
# Predicted:  Sweatshirts
# Target Laptop Bag
# Predicted:  Duffel Bag
# Target Shorts
# Predicted:  Capris
# Target Night suits
# Predicted:  Kurta Sets
# Target Sweatshirts
# Predicted:  Sweatshirts
# Target Night suits
# Predicted:  Night suits
# Target Jackets
# Predicted:  Jackets
# Target Duffel Bag
# Predicted:  Duffel Bag
# Target Trousers
# Predicted:  Trousers
# Target Night suits
# Predicted:  Kurta Sets
# Target Jackets
# Predicted:  Jackets
# Target Tunics
# Predicted:  Kurtis
# Target Backpacks
# Predicted:  Backpacks
# Target Jeans
# Predicted:  Jeans
# Target Sweatshirts
# Predicted:  Sweatshirts
# Target Pendant
# Predicted:  Pendant
# Target Track Pants
# Predicted:  Track Pants
# Target Backpacks
# Predicted:  Backpacks
# Target Shorts
# Predicted:  Shorts
# Target Trousers
# Predicted:  Trousers
# Target Nightdress
# Predicted:  Tunics
# Target Track Pants
# Predicted:  Track Pants
# Target Earrings
# Predicted:  Earrings
# Target Track Pants
# Predicted:  Track Pants
# Target Shorts
# Predicted:  Shorts
# Target Sweatshirts
# Predicted:  Sweatshirts
# Target Backpacks
# Predicted:  Backpacks
# Target Jeans
# Predicted:  Jeans
# Target Caps
# Predicted:  Caps
# Target Shorts
# Predicted:  Jumpsuit
# Target Jackets
# Predicted:  Jackets
# Target Leggings
# Predicted:  Leggings
# Target Jeans
# Predicted:  Jeans
# Target Trousers
# Predicted:  Trousers
# Target Backpacks
# Predicted:  Backpacks
# Target Backpacks
# Predicted:  Backpacks
# Target Earrings
# Predicted:  Earrings
# Target Sweaters
# Predicted:  Sweatshirts
# Target Bra
# Predicted:  Bra
# Target Ties
# Predicted:  Ties
# Target Bra
# Predicted:  Bra
# Target Shorts
# Predicted:  Shorts
# Target Shorts
# Predicted:  Shorts
# Target Trousers
# Predicted:  Trousers
# Target Trousers
# Predicted:  Trousers
# Target Sweaters
# Predicted:  Sweaters
# Target Nightdress
# Predicted:  Tunics
# Target Jeans
# Predicted:  Jeans
# Target Shoe Accessories
# Predicted:  Cufflinks
# Target Caps
# Predicted:  Caps
# Target Track Pants
# Predicted:  Capris
# Target Nightdress
# Predicted:  Tunics
# Target Basketballs
# Predicted:  Basketballs
# Target Stockings
# Predicted:  Track Pants
# Target Pendant
# Predicted:  Necklace and Chains
# Target Sports Sandals
# Predicted:  Sports Sandals
# Target Jackets
# Predicted:  Jackets
# Target Wristbands
# Predicted:  Wristbands
# Target Capris
# Predicted:  Capris
# Target Mobile Pouch
# Predicted:  Mobile Pouch
# Target Caps
# Predicted:  Caps
# Target Jeans
# Predicted:  Jeans
# Target Backpacks
# Predicted:  Backpacks
# Target Sweaters
# Predicted:  Sweaters
# Target Night suits
# Predicted:  Kurta Sets
# Target Jeans
# Predicted:  Jeans
# Target Trousers
# Predicted:  Trousers
# Target Jackets
# Predicted:  Jackets
# Target Jackets
# Predicted:  Jackets
# Target Trousers
# Predicted:  Trousers
# Target Pendant
# Predicted:  Pendant
# Target Bra
# Predicted:  Bra
# Target Caps
# Predicted:  Caps
# Target Shorts
# Predicted:  Shorts
# Target Nightdress
# Predicted:  Tunics
# Target Backpacks
# Predicted:  Backpacks
# Target Sweatshirts
# Predicted:  Sweatshirts
# Target Jeans
# Predicted:  Jeans
# Target Shapewear
# Predicted:  Nightdress
# Target Jackets
# Predicted:  Sweatshirts
# Target Caps
# Predicted:  Caps
# Target Sweatshirts
# Predicted:  Sweatshirts
# Target Nightdress
# Predicted:  Tunics
# Target Trousers
# Predicted:  Trousers
# Target Backpacks
# Predicted:  Backpacks
# Target Sweaters
# Predicted:  Sweaters
# Target Sweaters
# Predicted:  Sweatshirts
# Target Sports Sandals
# Predicted:  Sports Sandals
# Target Sports Sandals
# Predicted:  Sports Sandals
# Target Trousers
# Predicted:  Track Pants
# Target Duffel Bag
# Predicted:  Duffel Bag
# Target Necklace and Chains
# Predicted:  Necklace and Chains
# Target Pendant
# Predicted:  Pendant
# Target Bra
# Predicted:  Bra
# Target Sweatshirts
# Predicted:  Sweatshirts
# Target Backpacks
# Predicted:  Backpacks
# Target Sweatshirts
# Predicted:  Sweatshirts
# Target Bangle
# Predicted:  Bracelet
# Target Sweatshirts
# Predicted:  Sweatshirts
# Target Earrings
# Predicted:  Earrings
# Target Clutches
# Predicted:  Clutches
# Target Sweaters
# Predicted:  Sweatshirts
# Target Shorts
# Predicted:  Shorts
# Target Jackets
# Predicted:  Blazers
# Target Track Pants
# Predicted:  Track Pants
# Target Trousers
# Predicted:  Trousers
# Target Clutches
# Predicted:  Clutches
# Target Backpacks
# Predicted:  Backpacks
# Target Jeans
# Predicted:  Jeans
# Target Capris
# Predicted:  Shorts
# Target Trousers
# Predicted:  Trousers
# Target Skirts
# Predicted:  Skirts
# Target Backpacks
# Predicted:  Backpacks
# Target Duffel Bag
# Predicted:  Duffel Bag
# Target Backpacks
# Predicted:  Backpacks
# Target Night suits
# Predicted:  Kurta Sets
# Target Jackets
# Predicted:  Jackets
# Target Jeans
# Predicted:  Jeans
# Target Shorts
# Predicted:  Capris
# Target Shorts
# Predicted:  Lounge Shorts
# Target Backpacks
# Predicted:  Backpacks
# Target Backpacks
# Predicted:  Backpacks
# Target Messenger Bag
# Predicted:  Messenger Bag
# Target Sweatshirts
# Predicted:  Sweatshirts
# Target Night suits
# Predicted:  Kurta Sets
# Target Track Pants
# Predicted:  Track Pants
# Target Sweaters
# Predicted:  Kurtis
# Target Night suits
# Predicted:  Jumpsuit
# Target Leggings
# Predicted:  Leggings
# Target Capris
# Predicted:  Track Pants
# Target Nightdress
# Predicted:  Tunics
# Target Sweatshirts
# Predicted:  Sweatshirts
# Target Mobile Pouch
# Predicted:  Laptop Bag
# Target Jackets
# Predicted:  Jackets
# Target Trousers
# Predicted:  Trousers
# Target Trousers
# Predicted:  Trousers
# Target Track Pants
# Predicted:  Track Pants
# Target Shorts
# Predicted:  Lounge Shorts
# Target Track Pants
# Predicted:  Track Pants
# Target Caps
# Predicted:  Caps
# Target Earrings
# Predicted:  Earrings
# Target Sweatshirts
# Predicted:  Sweatshirts
# Target Jeans
# Predicted:  Trousers
# Target Trousers
# Predicted:  Trousers
# Target Key chain
# Predicted:  Ring
# Target Backpacks
# Predicted:  Backpacks
# Target Track Pants
# Predicted:  Track Pants
# Target Nightdress
# Predicted:  Tunics
# Target Jackets
# Predicted:  Jackets
# Target Sweaters
# Predicted:  Tunics
# Target Night suits
# Predicted:  Kurta Sets
# Target Sweatshirts
# Predicted:  Sweatshirts
# Target Backpacks
# Predicted:  Backpacks
# Target Backpacks
# Predicted:  Backpacks
# Target Camisoles
# Predicted:  Bra
# Target Sweatshirts
# Predicted:  Sweatshirts
# Target Pendant
# Predicted:  Pendant
# Target Trousers
# Predicted:  Track Pants
# Target Backpacks
# Predicted:  Backpacks
# Target Ties
# Predicted:  Ties
# Target Track Pants
# Predicted:  Track Pants
# Target Shorts
# Predicted:  Shorts
# Target Sweatshirts
# Predicted:  Sweatshirts
# Target Track Pants
# Predicted:  Track Pants
# Target Backpacks
# Predicted:  Backpacks
# Target Sweaters
# Predicted:  Sweatshirts
# Target Accessory Gift Set
# Predicted:  Accessory Gift Set
# Target Mufflers
# Predicted:  Scarves
# Target Jeans
# Predicted:  Jeans
# Target Accessory Gift Set
# Predicted:  Accessory Gift Set
# Target Sweatshirts
# Predicted:  Sweatshirts
# Target Trousers
# Predicted:  Trousers
# Target Skirts
# Predicted:  Skirts
# Target Bra
# Predicted:  Bra
# Target Sports Sandals
# Predicted:  Sports Sandals
# Target Leggings
# Predicted:  Capris
# Target Capris
# Predicted:  Capris
# Target Trousers
# Predicted:  Trousers
# Target Backpacks
# Predicted:  Backpacks
# Target Sweatshirts
# Predicted:  Sweatshirts
# Target Rain Jacket
# Predicted:  Rain Jacket
# Target Night suits
# Predicted:  Night suits
# Target Pendant
# Predicted:  Pendant
# Target Sweatshirts
# Predicted:  Sweatshirts
# Target Accessory Gift Set
# Predicted:  Accessory Gift Set
# Target Sweatshirts
# Predicted:  Jackets
# Target Accessory Gift Set
# Predicted:  Accessory Gift Set
# Target Backpacks
# Predicted:  Backpacks
# Target Backpacks
# Predicted:  Backpacks
# Target Earrings
# Predicted:  Earrings
# Target Nightdress
# Predicted:  Jumpsuit
# Target Cufflinks
# Predicted:  Cufflinks
# Target Jackets
# Predicted:  Jackets
# Target Track Pants
# Predicted:  Track Pants
# Target Trousers
# Predicted:  Trousers
# Target Track Pants
# Predicted:  Track Pants
# Target Accessory Gift Set
# Predicted:  Accessory Gift Set
# Target Backpacks
# Predicted:  Backpacks
# Target Ties
# Predicted:  Ties
# Target Earrings
# Predicted:  Earrings
# Target Pendant
# Predicted:  Pendant
# Target Sweatshirts
# Predicted:  Jackets
# Target Backpacks
# Predicted:  Backpacks
# Target Swimwear
# Predicted:  Shapewear
# Target Sweaters
# Predicted:  Jackets
# 6000
# Target Rucksacks
# Predicted:  Rucksacks
# Target Shorts
# Predicted:  Shorts
# Target Duffel Bag
# Predicted:  Duffel Bag
# Target Sweatshirts
# Predicted:  Sweaters
# Target Accessory Gift Set
# Predicted:  Accessory Gift Set
# Target Capris
# Predicted:  Track Pants
# Target Pendant
# Predicted:  Pendant
# Target Sweatshirts
# Predicted:  Sweatshirts
# Target Track Pants
# Predicted:  Track Pants
# Target Backpacks
# Predicted:  Backpacks
# Target Bra
# Predicted:  Bra
# Target Sweatshirts
# Predicted:  Sweatshirts
# Target Jeans
# Predicted:  Jeans
# Target Night suits
# Predicted:  Kurta Sets
# Target Leggings
# Predicted:  Capris
# Target Necklace and Chains
# Predicted:  Necklace and Chains
# Target Capris
# Predicted:  Capris
# Target Waist Pouch
# Predicted:  Duffel Bag
# ...
# Predicted:  Caps
# Target Shorts
# Predicted:  Capris
# Target Ties
# Predicted:  Ties
# Target Ring
# Predicted:  Ring
# Target Pendant
# Predicted:  Pendant
# Target Shorts
# Predicted:  Shorts
# Target Night suits
# Predicted:  Kurta Sets
# Target Capris
# Predicted:  Capris
# Target Trousers
# Predicted:  Trousers
# Target Capris
# Predicted:  Capris
# Target Ring
# Predicted:  Ring
# Target Duffel Bag
# Predicted:  Backpacks
# Target Trousers
# Predicted:  Trousers
# Target Nightdress
# Predicted:  Tunics
# Target Bra
# Predicted:  Bra
# Target Jeans
# Predicted:  Jeggings
# Target Scarves
# Predicted:  Shorts
# Target Sweatshirts
# Predicted:  Sweatshirts
# Target Ring
# Predicted:  Ring
# Target Accessory Gift Set
# Predicted:  Accessory Gift Set
# Target Kurta Sets
# Predicted:  Kurta Sets
# Target Shoe Accessories
# Predicted:  Makeup Remover
# Target Rucksacks
# Predicted:  Backpacks
# Target Jeans
# Predicted:  Capris
# Target Jeans
# Predicted:  Jeans
# Target Sweaters
# Predicted:  Sweatshirts
# Target Clutches
# Predicted:  Clutches
# Target Sweaters
# Predicted:  Sweaters
# Target Backpacks
# Predicted:  Backpacks
# Target Nightdress
# Predicted:  Nightdress
# Target Backpacks
# Predicted:  Backpacks
# Target Bangle
# Predicted:  Ring
# Target Sweaters
# Predicted:  Jackets
# Target Clutches
# Predicted:  Clutches
# Target Trousers
# Predicted:  Trousers
# Target Backpacks
# Predicted:  Backpacks
# Target Backpacks
# Predicted:  Backpacks
# Target Trousers
# Predicted:  Trousers
# Target Jeans
# Predicted:  Jeans
# Target Tracksuits
# Predicted:  Tracksuits
# Target Jeans
# Predicted:  Jeans
# Target Sweaters
# Predicted:  Sweaters
# Target Track Pants
# Predicted:  Track Pants
# Target Nightdress
# Predicted:  Nightdress
# Target Trousers
# Predicted:  Trousers
# Target Clutches
# Predicted:  Clutches
# Target Bra
# Predicted:  Bra
# Target Sweaters
# Predicted:  Sweaters
# Target Backpacks
# Predicted:  Backpacks
# Target Sweaters
# Predicted:  Sweatshirts
# Target Jackets
# Predicted:  Sweatshirts
# Target Camisoles
# Predicted:  Innerwear Vests
# Target Sweaters
# Predicted:  Sweaters
# Target Earrings
# Predicted:  Earrings
# Target Shorts
# Predicted:  Shorts
# Target Shorts
# Predicted:  Shorts
# Target Kurta Sets
# Predicted:  Kurta Sets
# Target Sports Sandals
# Predicted:  Sports Sandals
# Target Sweaters
# Predicted:  Sweaters
# Target Trousers
# Predicted:  Track Pants
# Target Sweatshirts
# Predicted:  Sweatshirts
# Target Jeans
# Predicted:  Jeans
# Target Ring
# Predicted:  Ring
# Target Shorts
# Predicted:  Shorts
# Target Clutches
# Predicted:  Clutches
# Target Jeans
# Predicted:  Jeggings
# Target Nightdress
# Predicted:  Nightdress
# Target Sweaters
# Predicted:  Blazers
# Target Track Pants
# Predicted:  Track Pants
# Target Earrings
# Predicted:  Earrings
# Target Sweaters
# Predicted:  Sweatshirts
# Target Bra
# Predicted:  Bra
# Target Sweaters
# Predicted:  Jackets
# Target Shoe Accessories
# Predicted:  Water Bottle
# Target Sports Sandals
# Predicted:  Sports Sandals
# Target Bra
# Predicted:  Bra
# Target Sweaters
# Predicted:  Sweatshirts
# Target Jeans
# Predicted:  Jeans
# Target Clutches
# Predicted:  Clutches
# Target Backpacks
# Predicted:  Backpacks
# Target Shorts
# Predicted:  Shorts
# Target Rucksacks
# Predicted:  Rucksacks
# Target Ties
# Predicted:  Ties
# Target Nightdress
# Predicted:  Nightdress
# Target Shorts
# Predicted:  Shorts
# Target Bra
# Predicted:  Bra
# Target Bra
# Predicted:  Bra
# Target Sweatshirts
# Predicted:  Sweatshirts
# Target Shorts
# Predicted:  Shorts
# Target Kurtis
# Predicted:  Tunics
# Target Bra
# Predicted:  Bra
# Target Ring
# Predicted:  Bangle
# Target Scarves
# Predicted:  Mufflers
# Target Scarves
# Predicted:  Mufflers
# Target Kurta Sets
# Predicted:  Kurta Sets
# Target Nightdress
# Predicted:  Nightdress
# Target Trousers
# Predicted:  Trousers
# Target Camisoles
# Predicted:  Tablet Sleeve
# Target Sweatshirts
# Predicted:  Sweatshirts
# Target Skirts
# Predicted:  Clothing Set
# Target Backpacks
# Predicted:  Backpacks
# Target Sweaters
# Predicted:  Sweatshirts
# Target Track Pants
# Predicted:  Shorts
# Target Free Gifts
# Predicted:  Makeup Remover
# Target Backpacks
# Predicted:  Backpacks
# Target Scarves
# Predicted:  Scarves
# Target Ring
# Predicted:  Ring
# Target Camisoles
# Predicted:  Shrug
# Target Tracksuits
# Predicted:  Tracksuits
# Target Track Pants
# Predicted:  Track Pants
# Target Bra
# Predicted:  Bra
# Target Kurtis
# Predicted:  Tunics
# Target Sweatshirts
# Predicted:  Sweatshirts
# Target Jeans
# Predicted:  Jeans
# Target Umbrellas
# Predicted:  Umbrellas
# Target Backpacks
# Predicted:  Backpacks
# Target Ties
# Predicted:  Ties
# Target Nightdress
# Predicted:  Tunics
# Target Jackets
# Predicted:  Sweatshirts
# Target Sweaters
# Predicted:  Sweatshirts
# Target Clutches
# Predicted:  Clutches
# Target Jeans
# Predicted:  Jeans
# Target Duffel Bag
# Predicted:  Duffel Bag
# Target Clutches
# Predicted:  Clutches
# Target Backpacks
# Predicted:  Backpacks
# Target Accessory Gift Set
# Predicted:  Accessory Gift Set
# Target Backpacks
# Predicted:  Backpacks
# Target Ties
# Predicted:  Ties
# Target Trousers
# Predicted:  Trousers
# Target Bra
# Predicted:  Bra
# Target Shorts
# Predicted:  Capris
# Target Jeans
# Predicted:  Jeans
# Target Jeans
# Predicted:  Jeans
# Target Trousers
# Predicted:  Track Pants
# Target Nightdress
# Predicted:  Tunics
# Target Bra
# Predicted:  Bra
# Target Scarves
# Predicted:  Mufflers
# Target Capris
# Predicted:  Capris
# Target Bra
# Predicted:  Bra
# Target Jackets
# Predicted:  Sweatshirts
# Target Kurtis
# Predicted:  Tunics
# Target Stoles
# Predicted:  Stoles
# Target Trousers
# Predicted:  Trousers
# Target Bracelet
# Predicted:  Bracelet
# Target Bra
# Predicted:  Bra
# Target Night suits
# Predicted:  Kurta Sets
# Target Sweatshirts
# Predicted:  Sweatshirts
# Target Pendant
# Predicted:  Pendant
# Target Sweaters
# Predicted:  Sweatshirts
# Target Ties
# Predicted:  Ties
# Target Bra
# Predicted:  Bra
# Target Bra
# Predicted:  Bra
# Target Trousers
# Predicted:  Shorts
# Target Pendant
# Predicted:  Necklace and Chains
# Target Camisoles
# Predicted:  Camisoles
# Target Shrug
# Predicted:  Sweaters
# Target Pendant
# Predicted:  Pendant
# Target Ties
# Predicted:  Ties
# Target Bra
# Predicted:  Bra
# Target Backpacks
# Predicted:  Backpacks
# Target Shorts
# Predicted:  Shorts
# Target Trousers
# Predicted:  Trousers
# Target Camisoles
# Predicted:  Shapewear
# Target Bra
# Predicted:  Bra
# Target Sweatshirts
# Predicted:  Sweatshirts
# Target Ties
# Predicted:  Ties
# Target Jackets
# Predicted:  Jackets
# Target Capris
# Predicted:  Capris
# Target Accessory Gift Set
# Predicted:  Accessory Gift Set
# Target Bra
# Predicted:  Bra
# Target Pendant
# Predicted:  Pendant
# Target Sweaters
# Predicted:  Sweatshirts
# Target Basketballs
# Predicted:  Footballs
# Target Bra
# Predicted:  Bra
# Target Backpacks
# Predicted:  Backpacks
# Target Pendant
# Predicted:  Ring
# Target Lounge Shorts
# Predicted:  Capris
# Target Shorts
# Predicted:  Capris
# Target Jeans
# Predicted:  Jeans
# Target Sweatshirts
# Predicted:  Sweatshirts
# Target Sweaters
# Predicted:  Sweatshirts
# Target Kurtis
# Predicted:  Kurtis
# Target Bra
# Predicted:  Bra
# Target Sweaters
# Predicted:  Sweaters
# Target Capris
# Predicted:  Capris
# Target Jeans
# Predicted:  Jeans
# Target Sweatshirts
# Predicted:  Sweaters
# Target Bra
# Predicted:  Bra
# Target Backpacks
# Predicted:  Backpacks
# Target Nightdress
# Predicted:  Tunics
# Target Jeans
# Predicted:  Jeans
# Target Trousers
# Predicted:  Capris
# Target Bra
# Predicted:  Bra
# Target Free Gifts
# Predicted:  Clutches
# Target Ties
# Predicted:  Ties
# Target Laptop Bag
# Predicted:  Backpacks
# Target Capris
# Predicted:  Night suits
# Target Bra
# Predicted:  Bra
# Target Ring
# Predicted:  Ring
# Target Jeans
# Predicted:  Leggings
# Target Bra
# Predicted:  Bra
# Target Backpacks
# Predicted:  Backpacks
# Target Trousers
# Predicted:  Trousers
# Target Night suits
# Predicted:  Kurta Sets
# Target Backpacks
# Predicted:  Backpacks
# Target Jackets
# Predicted:  Jackets
# Target Earrings
# Predicted:  Earrings
# Target Bracelet
# Predicted:  Bangle
# Target Sweaters
# Predicted:  Jackets
# Target Shorts
# Predicted:  Capris
# Target Clutches
# Predicted:  Clutches
# Target Nightdress
# Predicted:  Jumpsuit
# Target Jeans
# Predicted:  Jeans
# Target Tunics
# Predicted:  Tunics
# Target Sweatshirts
# Predicted:  Jackets
# Target Jeans
# Predicted:  Jeans
# Target Backpacks
# Predicted:  Backpacks
# Target Backpacks
# Predicted:  Backpacks
# Target Footballs
# Predicted:  Footballs
# Target Pendant
# Predicted:  Pendant
# Target Bra
# Predicted:  Bra
# Target Bracelet
# Predicted:  Bracelet
# Target Night suits
# Predicted:  Kurta Sets
# Target Jackets
# Predicted:  Jackets
# Target Track Pants
# Predicted:  Track Pants
# Target Jackets
# Predicted:  Blazers
# Target Bra
# Predicted:  Bra
# Target Skirts
# Predicted:  Nightdress
# Target Bra
# Predicted:  Bra
# Target Ties
# Predicted:  Ties
# Target Ring
# Predicted:  Ring
# Target Bra
# Predicted:  Bra
# Target Caps
# Predicted:  Caps
# Target Bangle
# Predicted:  Ring
# Target Backpacks
# Predicted:  Backpacks
# Target Sweaters
# Predicted:  Sweatshirts
# Target Shorts
# Predicted:  Shorts
# Target Bra
# Predicted:  Bra
# 20000
# Target Bra
# Predicted:  Bra
# Target Sweaters
# Predicted:  Sweatshirts
# Target Sweatshirts
# Predicted:  Sweatshirts
# Target Nightdress
# Predicted:  Nightdress
# Target Kurta Sets
# Predicted:  Kurta Sets
# Target Camisoles
# Predicted:  Clothing Set
# Target Trousers
# Predicted:  Trousers
# Target Duffel Bag
# Predicted:  Messenger Bag
# Target Nightdress
# Predicted:  Tunics
# Target Sweatshirts
# Predicted:  Sweatshirts
# Target Bra
# Predicted:  Bra
# Target Jeans
# Predicted:  Jeans
# Target Bra
# Predicted:  Bra
# Target Bra
# Predicted:  Bra
# Target Backpacks
# Predicted:  Backpacks
# Target Jackets
# Predicted:  Sweatshirts
# Target Waist Pouch
# Predicted:  Messenger Bag
# Target Clutches
# Predicted:  Clutches
# Target Jeans
# Predicted:  Jeans
# Target Jackets
# Predicted:  Jackets
# Target Backpacks
# Predicted:  Backpacks
# Target Free Gifts
# Predicted:  Makeup Remover
# Target Track Pants
# Predicted:  Track Pants
# Target Tracksuits
# Predicted:  Tracksuits
# Target Bra
# Predicted:  Bra
# Target Mobile Pouch
# Predicted:  Clutches
# Target Ring
# Predicted:  Ring
# Target Scarves
# Predicted:  Scarves
# Target Camisoles
# Predicted:  Camisoles
# Target Track Pants
# Predicted:  Track Pants
# Target Shoe Accessories
# Predicted:  Makeup Remover
# Target Bra
# Predicted:  Bra
# Target Shorts
# Predicted:  Shorts
# Target Nightdress
# Predicted:  Nightdress
# Target Sweaters
# Predicted:  Innerwear Vests
# Target Jeans
# Predicted:  Jeggings
# Target Clutches
# Predicted:  Clutches
# Target Skirts
# Predicted:  Nightdress
# Target Track Pants
# Predicted:  Track Pants
# Target Kurtis
# Predicted:  Kurtis
# Target Scarves
# Predicted:  Scarves
# Target Ring
# Predicted:  Bangle
# Target Tracksuits
# Predicted:  Tracksuits
# Target Kurtis
# Predicted:  Kurtis
# Target Bra
# Predicted:  Bra
# Target Jeans
# Predicted:  Jeans
# Target Shorts
# Predicted:  Shorts
# Target Jeans
# Predicted:  Jeans
# Target Scarves
# Predicted:  Scarves
# Target Tunics
# Predicted:  Kurtis
# Target Jackets
# Predicted:  Jackets
# Target Sweaters
# Predicted:  Sweatshirts
# Target Laptop Bag
# Predicted:  Backpacks
# Target Jeans
# Predicted:  Jeans
# Target Kurtis
# Predicted:  Kurtis
# Target Bra
# Predicted:  Bra
# Target Backpacks
# Predicted:  Backpacks
# Target Sweaters
# Predicted:  Sweaters
# Target Bra
# Predicted:  Bra
# Target Bra
# Predicted:  Bra
# Target Backpacks
# Predicted:  Backpacks
# Target Shorts
# Predicted:  Shorts
# Target Nightdress
# Predicted:  Jumpsuit
# Target Ties
# Predicted:  Ties
# Target Shorts
# Predicted:  Track Pants
# Target Sweaters
# Predicted:  Sweatshirts
# Target Free Gifts
# Predicted:  Water Bottle
# Target Track Pants
# Predicted:  Track Pants
# Target Clutches
# Predicted:  Clutches
# Target Backpacks
# Predicted:  Backpacks
# Target Trousers
# Predicted:  Trousers
# Target Backpacks
# Predicted:  Backpacks
# Target Shorts
# Predicted:  Shorts
# Target Track Pants
# Predicted:  Track Pants
# Target Jeans
# Predicted:  Jeggings
# Target Camisoles
# Predicted:  Camisoles
# Target Sweatshirts
# Predicted:  Sweatshirts
# Target Ring
# Predicted:  Ring
# Target Sweaters
# Predicted:  Sweaters
# Target Kurta Sets
# Predicted:  Kurta Sets
# Target Bra
# Predicted:  Bra
# Target Clutches
# Predicted:  Clutches
# Target Sweaters
# Predicted:  Sweaters
# Target Backpacks
# Predicted:  Backpacks
# Target Nightdress
# Predicted:  Camisoles
# Target Trousers
# Predicted:  Trousers
# Target Bangle
# Predicted:  Bangle
# Target Travel Accessory
# Predicted:  Messenger Bag
# Target Backpacks
# Predicted:  Backpacks
# Target Jeans
# Predicted:  Jeans
# Target Bra
# Predicted:  Bra
# Target Bra
# Predicted:  Bra
# Target Jeans
# Predicted:  Jeans
# Target Nightdress
# Predicted:  Tunics
# Target Sweatshirts
# Predicted:  Sweatshirts
# Target Capris
# Predicted:  Capris
# Target Ring
# Predicted:  Ring
# Target Jeans
# Predicted:  Jeans
# Target Sweaters
# Predicted:  Sweaters
# Target Track Pants
# Predicted:  Track Pants
# Target Nightdress
# Predicted:  Nightdress
# Target Backpacks
# Predicted:  Backpacks
# Target Clutches
# Predicted:  Clutches
# Target Sweaters
# Predicted:  Sweaters
# Target Rucksacks
# Predicted:  Backpacks
# Target Kurta Sets
# Predicted:  Kurta Sets
# Target Track Pants
# Predicted:  Track Pants
# Target Shoe Accessories
# Predicted:  Free Gifts
# Target Sweaters
# Predicted:  Sweatshirts
# Target Jeans
# Predicted:  Jeans
# Target Backpacks
# Predicted:  Backpacks
# Target Shorts
# Predicted:  Shorts
# Total Instances:  4159
# Overall Accuracy:  0.752103871122866
# class:
#  Track Pants
# top1:  0.8901734104046243
# top5:  0.9710982658959537
# class:
#  Sweatshirts
# top1:  0.8249027237354085
# top5:  0.9766536964980544
# class:
#  Shorts
# top1:  0.7535545023696683
# top5:  0.9715639810426541
# class:
#  Clutches
# top1:  0.9722222222222222
# top5:  1.0
# class:
#  Backpacks
# top1:  0.9664570230607966
# top5:  1.0
# class:
#  Caps
# top1:  0.8931297709923665
# top5:  0.9694656488549618
# class:
#  Trousers
# top1:  0.8084291187739464
# top5:  0.9846743295019157
# class:
#  Jeans
# top1:  0.8634686346863468
# top5:  0.992619926199262
# class:
#  Bra
# top1:  0.9848024316109423
# top5:  0.9908814589665653
# class:
#  Lounge Pants
# top1:  0.21052631578947367
# top5:  0.7894736842105263
# class:
#  Duffel Bag
# top1:  0.8043478260869565
# top5:  0.9782608695652174
# class:
#  Night suits
# top1:  0.1
# top5:  0.7714285714285715
# class:
#  Pendant
# top1:  0.8271604938271605
# top5:  0.9753086419753086
# class:
#  Tracksuits
# top1:  0.95
# top5:  1.0
# class:
#  Tunics
# top1:  0.5555555555555556
# top5:  1.0
# class:
#  Nightdress
# top1:  0.35625
# top5:  0.875
# class:
#  Ties
# top1:  0.9879518072289156
# top5:  0.9879518072289156
# class:
#  Leggings
# top1:  0.5208333333333334
# top5:  0.9375
# class:
#  Jackets
# top1:  0.574468085106383
# top5:  0.9521276595744681
# class:
#  Messenger Bag
# top1:  0.7083333333333334
# top5:  1.0
# class:
#  Mufflers
# top1:  0.1724137931034483
# top5:  1.0
# class:
#  Kurta Sets
# top1:  1.0
# top5:  1.0
# class:
#  Accessory Gift Set
# top1:  1.0
# top5:  1.0
# class:
#  Bracelet
# top1:  0.8095238095238095
# top5:  1.0
# class:
#  Kurtis
# top1:  0.6477272727272727
# top5:  1.0
# class:
#  Sweaters
# top1:  0.4627450980392157
# top5:  0.9333333333333333
# class:
#  Ring
# top1:  0.896551724137931
# top5:  1.0
# class:
#  Scarves
# top1:  0.5652173913043478
# top5:  0.8478260869565217
# class:
#  Earrings
# top1:  1.0
# top5:  1.0
# class:
#  Capris
# top1:  0.7307692307692307
# top5:  1.0
# class:
#  Skirts
# top1:  0.660377358490566
# top5:  0.9245283018867925
# class:
#  Headband
# top1:  1.0
# top5:  1.0
# class:
#  Sports Sandals
# top1:  0.9333333333333333
# top5:  1.0
# class:
#  Tights
# top1:  1.0
# top5:  1.0
# class:
#  Travel Accessory
# top1:  0.1
# top5:  1.0
# class:
#  Gloves
# top1:  1.0
# top5:  1.0
# class:
#  Mobile Pouch
# top1:  0.5555555555555556
# top5:  1.0
# class:
#  Wristbands
# top1:  1.0
# top5:  1.0
# class:
#  Stockings
# top1:  0.17647058823529413
# top5:  0.7058823529411765
# class:
#  Footballs
# top1:  1.0
# top5:  1.0
# class:
#  Jumpsuit
# top1:  0.5
# top5:  1.0
# class:
#  Free Gifts
# top1:  0.08333333333333333
# top5:  0.08333333333333333
# class:
#  Necklace and Chains
# top1:  0.975
# top5:  1.0
# class:
#  Cufflinks
# top1:  1.0
# top5:  1.0
# class:
#  Jewellery Set
# top1:  0.8461538461538461
# top5:  1.0
# class:
#  Laptop Bag
# top1:  0.2
# top5:  0.8857142857142857
# class:
#  Camisoles
# top1:  0.3235294117647059
# top5:  0.9705882352941176
# class:
#  Rucksacks
# top1:  0.375
# top5:  1.0
# class:
#  Swimwear
# top1:  0.125
# top5:  0.875
# class:
#  Stoles
# top1:  0.5
# top5:  1.0
# class:
#  Basketballs
# top1:  0.6363636363636364
# top5:  1.0
# class:
#  Rain Jacket
# top1:  1.0
# top5:  1.0
# class:
#  Churidar
# top1:  0.5
# top5:  0.75
# class:
#  Umbrellas
# top1:  1.0
# top5:  1.0
# class:
#  Bangle
# top1:  0.08695652173913043
# top5:  1.0
# class:
#  Dupatta
# top1:  0.5
# top5:  1.0
# class:
#  Water Bottle
# top1:  1.0
# top5:  1.0
# class:
#  Makeup Remover
# top1:  0.6666666666666666
# top5:  1.0
# class:
#  Rain Trousers
# top1:  1.0
# top5:  1.0
# class:
#  Waist Pouch
# top1:  0.07692307692307693
# top5:  0.7692307692307693
