# %%
import torch
import numpy as np
from torchvision import datasets, transforms
from model import ResNetFashion
from data_loader import FashionDataset

# %%
def calc(model, dataset_loader, train_label_map, test_label_map, batch_size=1):
    top1_classes = {}
    top5_classes = {}
    totals = {}
    model.eval()
    for i, (data, target) in enumerate(dataset_loader):
        reversed_map = {v:k for k,v in test_label_map.items()}
        rev_map_train = {v:k for k,v in train_label_map.items()}
        key = reversed_map[target[0].item()]
        if key in train_label_map.keys():  # consider classes present in train set only
            if key not in totals:
                totals[key] = 1
            else:
                totals[key] += 1
            print("Target", reversed_map[target[0].item()])
            if cuda:
                data, target = data.cuda(), target.cuda()
            output = model(data)
            _, pred = torch.max(output, 1)
            output_idx = output.argmax(dim=1, keepdim=True)
            print("Predicted: ", rev_map_train[output_idx[0].item()])
            top1 = rev_map_train[output_idx[0].item()] == reversed_map[target[0].item()]
            top5 = (output.topk(5)[1]==train_label_map[reversed_map[target[0].item()]]).nonzero().numel()>0
            if top1:
                if key not in top1_classes:
                    top1_classes[key]= 1
                else:
                    top1_classes[key] += 1
            if top5:
                if key not in top5_classes:
                    top5_classes[key]= 1
                else:
                    top5_classes[key] += 1
            if i%1000==0:
                print(i)
          
    
    print("Total Instances: ", sum(list(totals.values())))
    print("Overall Accuracy: ", sum(list(top1_classes.values()))/sum(list(totals.values())))
    for lbl in top1_classes:
        print("class: \n", lbl)
        print("top1: ", top1_classes[lbl]/totals[lbl])
        print("top5: ", top5_classes[lbl]/totals[lbl])

# %%
from data_loader import FashionDataset
cuda = torch.cuda.is_available()

transforms_ = transforms.Compose([transforms.Resize((224,224)), transforms.ToTensor()])
data = FashionDataset("D:\\Projects\\Datasets\\fashion-larger","test_set.csv", transform=transforms_)
dataset_loader = torch.utils.data.DataLoader(dataset=data, batch_size=1)
model = ResNetFashion(num_classes=20)
model.cuda()
cp = torch.load("D:\\Projects\\Datasets\\fashion-larger\\model_output\\top20classes_loss_weight_sgd_moreepochs\\fashion-0.pth")
label_map = cp['label_map']
# label_map = {'Watches': 0, 'Tshirts': 1, 'Shirts': 2, 'Socks': 3, 'Belts': 4, 'Handbags': 5, 'Flip Flops': 6, 'Tops': 7, 'Casual Shoes': 8, 'Flats': 9, 'Kurtas': 10, 'Sports Shoes': 11, 'Briefs': 12, 'Formal Shoes': 13, 'Sarees': 14, 'Heels': 15, 'Sunglasses': 16, 'Dresses': 17, 'Wallets': 18, 'Sandals': 19}
model.load_state_dict(cp['state_dict'])
calc(model,dataset_loader, label_map, data.label_map)
# Out:
# Found 20635 images in D:\Projects\Datasets\fashion-larger for provided csv file.
# Total classes: 122
# Target Shirts
# Predicted:  Shirts
# 0
# Target Tshirts
# Predicted:  Tshirts
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Flip Flops
# Predicted:  Flip Flops
# Target Shirts
# Predicted:  Shirts
# Target Sandals
# Predicted:  Sandals
# Target Formal Shoes
# Predicted:  Formal Shoes
# Target Tshirts
# Predicted:  Tshirts
# Target Handbags
# Predicted:  Handbags
# Target Tshirts
# Predicted:  Tshirts
# Target Kurtas
# Predicted:  Kurtas
# Target Tshirts
# Predicted:  Tops
# Target Belts
# Predicted:  Belts
# Target Flats
# Predicted:  Flats
# Target Shirts
# Predicted:  Shirts
# Target Tshirts
# Predicted:  Tshirts
# Target Shirts
# Predicted:  Shirts
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Shirts
# Predicted:  Shirts
# Target Tshirts
# Predicted:  Tshirts
# Target Heels
# Predicted:  Sandals
# Target Sandals
# Predicted:  Sandals
# Target Flip Flops
# Predicted:  Flip Flops
# Target Tshirts
# Predicted:  Tshirts
# Target Flip Flops
# Predicted:  Flip Flops
# Target Tshirts
# Predicted:  Tshirts
# Target Sandals
# Predicted:  Sandals
# Target Casual Shoes
# Predicted:  Sports Shoes
# Target Flip Flops
# Predicted:  Flip Flops
# Target Tshirts
# Predicted:  Tshirts
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Shirts
# Predicted:  Shirts
# Target Heels
# Predicted:  Heels
# Target Wallets
# Predicted:  Wallets
# Target Tshirts
# Predicted:  Tshirts
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Shirts
# Predicted:  Shirts
# Target Sandals
# Predicted:  Flats
# Target Tshirts
# Predicted:  Tshirts
# Target Sandals
# Predicted:  Sandals
# Target Shirts
# Predicted:  Shirts
# Target Tshirts
# Predicted:  Tshirts
# Target Shirts
# Predicted:  Shirts
# Target Tshirts
# Predicted:  Tshirts
# Target Casual Shoes
# Predicted:  Sports Shoes
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Casual Shoes
# Predicted:  Sports Shoes
# Target Flats
# Predicted:  Heels
# Target Handbags
# Predicted:  Handbags
# Target Shirts
# Predicted:  Shirts
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Belts
# Predicted:  Belts
# Target Formal Shoes
# Predicted:  Formal Shoes
# Target Belts
# Predicted:  Belts
# Target Shirts
# Predicted:  Shirts
# Target Handbags
# Predicted:  Handbags
# Target Formal Shoes
# Predicted:  Formal Shoes
# Target Tops
# Predicted:  Tops
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Tops
# Predicted:  Tops
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Tshirts
# Predicted:  Tshirts
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Kurtas
# Predicted:  Kurtas
# Target Handbags
# Predicted:  Handbags
# Target Tshirts
# Predicted:  Tshirts
# Target Flip Flops
# Predicted:  Flip Flops
# Target Tshirts
# Predicted:  Tops
# Target Tops
# Predicted:  Tops
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Tops
# Predicted:  Tshirts
# Target Flip Flops
# Predicted:  Flip Flops
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Flip Flops
# Predicted:  Flip Flops
# Target Flip Flops
# Predicted:  Sandals
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Shirts
# Predicted:  Shirts
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Shirts
# Predicted:  Shirts
# Target Kurtas
# Predicted:  Kurtas
# Target Shirts
# Predicted:  Shirts
# Target Heels
# Predicted:  Heels
# Target Tops
# Predicted:  Tops
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Sandals
# Predicted:  Sandals
# Target Briefs
# Predicted:  Briefs
# Target Tops
# Predicted:  Tops
# Target Tshirts
# Predicted:  Tshirts
# Target Wallets
# Predicted:  Wallets
# Target Tshirts
# Predicted:  Tshirts
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Shirts
# Predicted:  Shirts
# Target Tshirts
# Predicted:  Tshirts
# Target Flip Flops
# Predicted:  Flip Flops
# Target Sandals
# Predicted:  Sandals
# Target Shirts
# Predicted:  Shirts
# Target Handbags
# Predicted:  Handbags
# Target Shirts
# Predicted:  Shirts
# Target Dresses
# Predicted:  Dresses
# Target Handbags
# Predicted:  Handbags
# Target Handbags
# Predicted:  Handbags
# Target Shirts
# Predicted:  Tops
# Target Socks
# Predicted:  Socks
# Target Tshirts
# Predicted:  Tshirts
# Target Formal Shoes
# Predicted:  Formal Shoes
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Wallets
# Predicted:  Wallets
# Target Tshirts
# Predicted:  Tshirts
# Target Shirts
# Predicted:  Shirts
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Flip Flops
# Predicted:  Flip Flops
# Target Tshirts
# Predicted:  Tshirts
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Sandals
# Predicted:  Sandals
# Target Shirts
# Predicted:  Shirts
# Target Wallets
# Predicted:  Wallets
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tops
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Tshirts
# Predicted:  Tshirts
# Target Shirts
# Predicted:  Shirts
# Target Shirts
# Predicted:  Shirts
# Target Flip Flops
# Predicted:  Flats
# Target Tshirts
# Predicted:  Tshirts
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Shirts
# Predicted:  Shirts
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Shirts
# Predicted:  Shirts
# Target Tshirts
# Predicted:  Tops
# Target Shirts
# Predicted:  Shirts
# Target Shirts
# Predicted:  Shirts
# Target Handbags
# Predicted:  Handbags
# Target Handbags
# Predicted:  Handbags
# Target Tshirts
# Predicted:  Tshirts
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Shirts
# Predicted:  Shirts
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Tops
# Predicted:  Tops
# Target Tshirts
# Predicted:  Tshirts
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Tshirts
# Predicted:  Tshirts
# Target Tops
# Predicted:  Shirts
# Target Wallets
# Predicted:  Wallets
# Target Socks
# Predicted:  Socks
# Target Tshirts
# Predicted:  Tshirts
# Target Sandals
# Predicted:  Sandals
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Flip Flops
# Predicted:  Flip Flops
# Target Formal Shoes
# Predicted:  Formal Shoes
# Target Wallets
# Predicted:  Wallets
# Target Tshirts
# Predicted:  Tshirts
# Target Formal Shoes
# Predicted:  Formal Shoes
# Target Shirts
# Predicted:  Shirts
# Target Handbags
# Predicted:  Handbags
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Shirts
# Predicted:  Shirts
# Target Handbags
# Predicted:  Handbags
# Target Heels
# Predicted:  Flats
# Target Tshirts
# Predicted:  Tshirts
# Target Sandals
# Predicted:  Sandals
# Target Tshirts
# Predicted:  Tshirts
# Target Heels
# Predicted:  Heels
# Target Shirts
# Predicted:  Shirts
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Shirts
# Predicted:  Shirts
# Target Sandals
# Predicted:  Sandals
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Flip Flops
# Predicted:  Flip Flops
# Target Shirts
# Predicted:  Shirts
# Target Casual Shoes
# Predicted:  Sports Shoes
# Target Sports Shoes
# Predicted:  Casual Shoes
# Target Kurtas
# Predicted:  Kurtas
# Target Tshirts
# Predicted:  Tshirts
# Target Heels
# Predicted:  Heels
# Target Tshirts
# Predicted:  Tops
# Target Flip Flops
# Predicted:  Flip Flops
# Target Shirts
# Predicted:  Shirts
# Target Tshirts
# Predicted:  Tshirts
# Target Flip Flops
# Predicted:  Flip Flops
# Target Dresses
# Predicted:  Dresses
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Shirts
# Predicted:  Shirts
# Target Tshirts
# Predicted:  Tshirts
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Tshirts
# Predicted:  Tops
# Target Tops
# Predicted:  Tops
# Target Shirts
# Predicted:  Shirts
# Target Tops
# Predicted:  Tshirts
# Target Kurtas
# Predicted:  Kurtas
# Target Tshirts
# Predicted:  Tshirts
# Target Shirts
# Predicted:  Shirts
# Target Handbags
# Predicted:  Handbags
# Target Tshirts
# Predicted:  Tops
# Target Flats
# Predicted:  Heels
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Tshirts
# Predicted:  Tshirts
# Target Tops
# Predicted:  Tshirts
# Target Belts
# Predicted:  Belts
# Target Kurtas
# Predicted:  Shirts
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Belts
# Predicted:  Belts
# Target Tshirts
# Predicted:  Tshirts
# Target Shirts
# Predicted:  Shirts
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Shirts
# Predicted:  Shirts
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Shirts
# Predicted:  Shirts
# Target Tshirts
# Predicted:  Tshirts
# Target Handbags
# Predicted:  Handbags
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Formal Shoes
# Predicted:  Formal Shoes
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Wallets
# Predicted:  Wallets
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Sandals
# Predicted:  Sports Shoes
# Target Tshirts
# Predicted:  Tshirts
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Shirts
# Predicted:  Shirts
# Target Shirts
# Predicted:  Shirts
# Target Tops
# Predicted:  Tops
# Target Tshirts
# Predicted:  Tshirts
# Target Kurtas
# Predicted:  Kurtas
# Target Tshirts
# Predicted:  Tshirts
# Target Wallets
# Predicted:  Wallets
# Target Tshirts
# Predicted:  Tshirts
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Handbags
# Predicted:  Handbags
# Target Tshirts
# Predicted:  Tops
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Handbags
# Predicted:  Handbags
# Target Shirts
# Predicted:  Shirts
# Target Tshirts
# Predicted:  Tshirts
# Target Handbags
# Predicted:  Handbags
# Target Dresses
# Predicted:  Dresses
# Target Shirts
# Predicted:  Shirts
# Target Shirts
# Predicted:  Shirts
# Target Belts
# Predicted:  Belts
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Shirts
# Predicted:  Shirts
# Target Shirts
# Predicted:  Shirts
# Target Shirts
# Predicted:  Shirts
# Target Watches
# Predicted:  Watches
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Flip Flops
# Predicted:  Sandals
# Target Tshirts
# Predicted:  Tshirts
# Target Formal Shoes
# Predicted:  Formal Shoes
# Target Belts
# Predicted:  Belts
# Target Tops
# Predicted:  Tops
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Shirts
# Predicted:  Shirts
# Target Handbags
# Predicted:  Handbags
# Target Belts
# Predicted:  Belts
# Target Wallets
# Predicted:  Wallets
# Target Heels
# Predicted:  Heels
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Flip Flops
# Predicted:  Flip Flops
# Target Flats
# Predicted:  Heels
# Target Shirts
# Predicted:  Shirts
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Belts
# Predicted:  Belts
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Shirts
# Predicted:  Shirts
# Target Flip Flops
# Predicted:  Flip Flops
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Flip Flops
# Predicted:  Flip Flops
# Target Sandals
# Predicted:  Sandals
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Shirts
# Predicted:  Shirts
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Shirts
# Predicted:  Shirts
# Target Tshirts
# Predicted:  Tshirts
# Target Handbags
# Predicted:  Handbags
# Target Heels
# Predicted:  Flats
# Target Tshirts
# Predicted:  Tshirts
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Shirts
# Predicted:  Shirts
# Target Tops
# Predicted:  Tshirts
# Target Shirts
# Predicted:  Shirts
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Heels
# Predicted:  Heels
# Target Heels
# Predicted:  Flats
# Target Flip Flops
# Predicted:  Flip Flops
# Target Belts
# Predicted:  Belts
# Target Tshirts
# Predicted:  Tshirts
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Handbags
# Predicted:  Handbags
# Target Tshirts
# Predicted:  Tshirts
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Handbags
# Predicted:  Handbags
# Target Casual Shoes
# Predicted:  Sports Shoes
# Target Formal Shoes
# Predicted:  Formal Shoes
# Target Tshirts
# Predicted:  Tshirts
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Heels
# Predicted:  Heels
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Shirts
# Predicted:  Shirts
# Target Tshirts
# Predicted:  Tshirts
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Shirts
# Predicted:  Shirts
# Target Heels
# Predicted:  Flats
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Shirts
# Predicted:  Shirts
# Target Tshirts
# Predicted:  Tops
# Target Formal Shoes
# Predicted:  Formal Shoes
# Target Casual Shoes
# Predicted:  Handbags
# Target Tshirts
# Predicted:  Tshirts
# Target Casual Shoes
# Predicted:  Formal Shoes
# Target Kurtas
# Predicted:  Kurtas
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Shirts
# Predicted:  Tops
# Target Tshirts
# Predicted:  Tshirts
# Target Handbags
# Predicted:  Handbags
# Target Heels
# Predicted:  Heels
# Target Tops
# Predicted:  Tops
# Target Handbags
# Predicted:  Handbags
# Target Shirts
# Predicted:  Shirts
# Target Tshirts
# Predicted:  Tshirts
# Target Shirts
# Predicted:  Shirts
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Tshirts
# Predicted:  Tshirts
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Tshirts
# Predicted:  Tshirts
# Target Briefs
# Predicted:  Briefs
# Target Tshirts
# Predicted:  Tshirts
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Tops
# Predicted:  Tops
# Target Tshirts
# Predicted:  Tshirts
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Handbags
# Predicted:  Handbags
# Target Tshirts
# Predicted:  Tshirts
# Target Shirts
# Predicted:  Shirts
# Target Shirts
# Predicted:  Shirts
# Target Shirts
# Predicted:  Shirts
# Target Tops
# Predicted:  Tops
# Target Dresses
# Predicted:  Dresses
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Shirts
# Predicted:  Shirts
# Target Wallets
# Predicted:  Wallets
# Target Socks
# Predicted:  Socks
# Target Shirts
# Predicted:  Shirts
# Target Shirts
# Predicted:  Shirts
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Shirts
# Predicted:  Shirts
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Flip Flops
# Predicted:  Flip Flops
# Target Flip Flops
# Predicted:  Flip Flops
# Target Tshirts
# Predicted:  Tshirts
# Target Handbags
# Predicted:  Handbags
# Target Handbags
# Predicted:  Handbags
# Target Casual Shoes
# Predicted:  Sports Shoes
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Casual Shoes
# Predicted:  Sports Shoes
# Target Tshirts
# Predicted:  Tops
# Target Tops
# Predicted:  Tops
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Shirts
# Predicted:  Shirts
# Target Kurtas
# Predicted:  Kurtas
# Target Tshirts
# Predicted:  Tshirts
# Target Shirts
# Predicted:  Shirts
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Shirts
# Predicted:  Shirts
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Tshirts
# Predicted:  Briefs
# Target Flip Flops
# Predicted:  Sandals
# Target Tshirts
# Predicted:  Tshirts
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Shirts
# Predicted:  Shirts
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Tshirts
# Predicted:  Tshirts
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Belts
# Predicted:  Belts
# Target Sandals
# Predicted:  Sandals
# Target Heels
# Predicted:  Flats
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Shirts
# Predicted:  Shirts
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Handbags
# Predicted:  Handbags
# Target Tshirts
# Predicted:  Tshirts
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Handbags
# Predicted:  Handbags
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Sandals
# Predicted:  Sandals
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Tshirts
# Predicted:  Tshirts
# Target Shirts
# Predicted:  Shirts
# Target Tshirts
# Predicted:  Tshirts
# Target Formal Shoes
# Predicted:  Formal Shoes
# Target Sandals
# Predicted:  Sandals
# Target Shirts
# Predicted:  Shirts
# Target Tshirts
# Predicted:  Tshirts
# Target Shirts
# Predicted:  Shirts
# Target Heels
# Predicted:  Flats
# Target Handbags
# Predicted:  Handbags
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Shirts
# Predicted:  Shirts
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Tshirts
# Predicted:  Tshirts
# Target Sandals
# Predicted:  Sandals
# Target Flats
# Predicted:  Casual Shoes
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Flip Flops
# Predicted:  Flip Flops
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Tshirts
# Predicted:  Tshirts
# Target Shirts
# Predicted:  Shirts
# Target Shirts
# Predicted:  Shirts
# Target Briefs
# Predicted:  Briefs
# Target Handbags
# Predicted:  Handbags
# Target Tshirts
# Predicted:  Tops
# Target Flip Flops
# Predicted:  Flip Flops
# Target Tshirts
# Predicted:  Tshirts
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Sandals
# Predicted:  Sandals
# Target Tshirts
# Predicted:  Tshirts
# Target Socks
# Predicted:  Socks
# Target Briefs
# Predicted:  Briefs
# Target Tops
# Predicted:  Tops
# Target Tshirts
# Predicted:  Tshirts
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Tops
# Predicted:  Tops
# Target Belts
# Predicted:  Belts
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Socks
# Predicted:  Wallets
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Tshirts
# Predicted:  Tshirts
# Target Socks
# Predicted:  Socks
# Target Handbags
# Predicted:  Handbags
# Target Wallets
# Predicted:  Wallets
# Target Heels
# Predicted:  Flats
# Target Kurtas
# Predicted:  Kurtas
# Target Flip Flops
# Predicted:  Flats
# Target Sports Shoes
# Predicted:  Casual Shoes
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Heels
# Predicted:  Flats
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Shirts
# Predicted:  Shirts
# Target Belts
# Predicted:  Belts
# Target Heels
# Predicted:  Flats
# Target Sandals
# Predicted:  Sandals
# Target Handbags
# Predicted:  Handbags
# Target Handbags
# Predicted:  Handbags
# Target Wallets
# Predicted:  Wallets
# Target Tops
# Predicted:  Tops
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Shirts
# Predicted:  Shirts
# Target Tshirts
# Predicted:  Tshirts
# Target Tops
# Predicted:  Tops
# Target Tshirts
# Predicted:  Tshirts
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Formal Shoes
# Predicted:  Formal Shoes
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Shirts
# Predicted:  Shirts
# Target Handbags
# Predicted:  Handbags
# Target Handbags
# Predicted:  Handbags
# Target Sports Shoes
# Predicted:  Casual Shoes
# Target Tshirts
# Predicted:  Tops
# Target Kurtas
# Predicted:  Dresses
# Target Shirts
# Predicted:  Shirts
# Target Tshirts
# Predicted:  Tops
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Heels
# Predicted:  Heels
# Target Tshirts
# Predicted:  Tshirts
# Target Sports Shoes
# Predicted:  Casual Shoes
# Target Kurtas
# Predicted:  Kurtas
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Flip Flops
# Predicted:  Shirts
# Target Tshirts
# Predicted:  Tops
# Target Briefs
# Predicted:  Briefs
# Target Shirts
# Predicted:  Shirts
# Target Casual Shoes
# Predicted:  Sports Shoes
# Target Tshirts
# Predicted:  Tshirts
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Shirts
# Predicted:  Shirts
# Target Tshirts
# Predicted:  Tshirts
# Target Formal Shoes
# Predicted:  Formal Shoes
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tops
# Target Heels
# Predicted:  Flats
# Target Kurtas
# Predicted:  Kurtas
# Target Shirts
# Predicted:  Shirts
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Sunglasses
# Predicted:  Sunglasses
# Target Casual Shoes
# Predicted:  Sports Shoes
# Target Flip Flops
# Predicted:  Flats
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Tshirts
# Predicted:  Tshirts
# Target Casual Shoes
# Predicted:  Sports Shoes
# Target Tops
# Predicted:  Tops
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Shirts
# Predicted:  Shirts
# Target Tshirts
# Predicted:  Tshirts
# Target Shirts
# Predicted:  Shirts
# Target Heels
# Predicted:  Heels
# Target Tshirts
# Predicted:  Tshirts
# Target Heels
# Predicted:  Heels
# Target Kurtas
# Predicted:  Kurtas
# Target Tshirts
# Predicted:  Tshirts
# Target Belts
# Predicted:  Belts
# Target Tshirts
# Predicted:  Tshirts
# Target Shirts
# Predicted:  Shirts
# Target Tops
# Predicted:  Tops
# Target Tshirts
# Predicted:  Tshirts
# Target Casual Shoes
# Predicted:  Sports Shoes
# Target Shirts
# Predicted:  Shirts
# Target Sandals
# Predicted:  Sandals
# Target Tshirts
# Predicted:  Tshirts
# Target Kurtas
# Predicted:  Kurtas
# Target Tshirts
# Predicted:  Tshirts
# Target Heels
# Predicted:  Flats
# Target Kurtas
# Predicted:  Kurtas
# Target Tshirts
# Predicted:  Tshirts
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Tshirts
# Predicted:  Tops
# Target Sandals
# Predicted:  Sandals
# Target Handbags
# Predicted:  Handbags
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Tshirts
# Predicted:  Tshirts
# Target Shirts
# Predicted:  Shirts
# Target Kurtas
# Predicted:  Kurtas
# Target Kurtas
# Predicted:  Kurtas
# Target Tshirts
# Predicted:  Tops
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Tshirts
# Predicted:  Tshirts
# Target Casual Shoes
# Predicted:  Sports Shoes
# Target Shirts
# Predicted:  Shirts
# Target Shirts
# Predicted:  Shirts
# Target Tshirts
# Predicted:  Tshirts
# Target Tops
# Predicted:  Tops
# Target Heels
# Predicted:  Heels
# Target Tshirts
# Predicted:  Tshirts
# Target Dresses
# Predicted:  Tops
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Handbags
# Predicted:  Handbags
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Tshirts
# Predicted:  Tshirts
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Tshirts
# Predicted:  Tshirts
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Tshirts
# Predicted:  Tshirts
# Target Casual Shoes
# Predicted:  Sports Shoes
# Target Tops
# Predicted:  Tops
# Target Tshirts
# Predicted:  Tshirts
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Socks
# Predicted:  Watches
# Target Socks
# Predicted:  Socks
# Target Handbags
# Predicted:  Handbags
# Target Casual Shoes
# Predicted:  Sports Shoes
# Target Kurtas
# Predicted:  Kurtas
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Briefs
# Predicted:  Briefs
# Target Tops
# Predicted:  Tops
# Target Tops
# Predicted:  Dresses
# Target Tshirts
# Predicted:  Tops
# Target Sandals
# Predicted:  Sandals
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Kurtas
# Predicted:  Kurtas
# Target Flip Flops
# Predicted:  Flip Flops
# Target Flip Flops
# Predicted:  Flip Flops
# Target Tshirts
# Predicted:  Tshirts
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Tshirts
# Predicted:  Tops
# Target Tshirts
# Predicted:  Tshirts
# Target Shirts
# Predicted:  Shirts
# Target Tshirts
# Predicted:  Tshirts
# Target Handbags
# Predicted:  Handbags
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Handbags
# Predicted:  Handbags
# Target Tshirts
# Predicted:  Tshirts
# Target Sandals
# Predicted:  Sandals
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Flats
# Predicted:  Sandals
# Target Shirts
# Predicted:  Shirts
# Target Tshirts
# Predicted:  Tshirts
# Target Shirts
# Predicted:  Shirts
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Briefs
# Predicted:  Briefs
# Target Belts
# Predicted:  Belts
# Target Belts
# Predicted:  Belts
# Target Handbags
# Predicted:  Handbags
# Target Heels
# Predicted:  Heels
# Target Tshirts
# Predicted:  Kurtas
# Target Tshirts
# Predicted:  Tshirts
# Target Shirts
# Predicted:  Shirts
# Target Kurtas
# Predicted:  Kurtas
# Target Tshirts
# Predicted:  Tshirts
# Target Shirts
# Predicted:  Shirts
# Target Briefs
# Predicted:  Briefs
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Sandals
# Predicted:  Sandals
# Target Shirts
# Predicted:  Shirts
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Casual Shoes
# Predicted:  Sports Shoes
# Target Casual Shoes
# Predicted:  Formal Shoes
# Target Tshirts
# Predicted:  Tshirts
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Flip Flops
# Predicted:  Flip Flops
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Handbags
# Predicted:  Handbags
# Target Belts
# Predicted:  Belts
# Target Shirts
# Predicted:  Shirts
# Target Tops
# Predicted:  Tops
# Target Shirts
# Predicted:  Shirts
# Target Shirts
# Predicted:  Shirts
# Target Watches
# Predicted:  Watches
# Target Tshirts
# Predicted:  Tshirts
# Target Kurtas
# Predicted:  Kurtas
# Target Shirts
# Predicted:  Shirts
# Target Handbags
# Predicted:  Handbags
# Target Shirts
# Predicted:  Shirts
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Wallets
# Predicted:  Wallets
# Target Tshirts
# Predicted:  Tshirts
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Wallets
# Predicted:  Wallets
# Target Kurtas
# Predicted:  Kurtas
# Target Shirts
# Predicted:  Shirts
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Tops
# Predicted:  Tops
# Target Tshirts
# Predicted:  Tshirts
# Target Kurtas
# Predicted:  Kurtas
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Shirts
# Predicted:  Shirts
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Dresses
# Predicted:  Dresses
# Target Handbags
# Predicted:  Handbags
# Target Sunglasses
# Predicted:  Sunglasses
# Target Shirts
# Predicted:  Shirts
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Kurtas
# Predicted:  Kurtas
# Target Shirts
# Predicted:  Shirts
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Tops
# Predicted:  Tops
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Kurtas
# Predicted:  Kurtas
# Target Briefs
# Predicted:  Briefs
# Target Tshirts
# Predicted:  Tshirts
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Shirts
# Predicted:  Shirts
# Target Tshirts
# Predicted:  Tshirts
# Target Briefs
# Predicted:  Briefs
# Target Shirts
# Predicted:  Shirts
# Target Tshirts
# Predicted:  Tshirts
# Target Heels
# Predicted:  Heels
# Target Tshirts
# Predicted:  Tshirts
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Heels
# Predicted:  Heels
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Tshirts
# Predicted:  Tshirts
# Target Sandals
# Predicted:  Sandals
# Target Briefs
# Predicted:  Briefs
# Target Tshirts
# Predicted:  Tshirts
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Tshirts
# Predicted:  Tshirts
# Target Flats
# Predicted:  Flats
# Target Tshirts
# Predicted:  Tshirts
# Target Tops
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Kurtas
# Predicted:  Shirts
# Target Handbags
# Predicted:  Handbags
# Target Tshirts
# Predicted:  Tshirts
# Target Handbags
# Predicted:  Handbags
# Target Heels
# Predicted:  Flats
# Target Handbags
# Predicted:  Handbags
# Target Sandals
# Predicted:  Sandals
# Target Shirts
# Predicted:  Shirts
# Target Heels
# Predicted:  Heels
# Target Tshirts
# Predicted:  Tops
# Target Tshirts
# Predicted:  Tshirts
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Belts
# Predicted:  Belts
# Target Tshirts
# Predicted:  Tops
# Target Handbags
# Predicted:  Handbags
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Tshirts
# Predicted:  Tshirts
# Target Wallets
# Predicted:  Wallets
# Target Kurtas
# Predicted:  Kurtas
# Target Flip Flops
# Predicted:  Flip Flops
# Target Tshirts
# Predicted:  Tshirts
# Target Heels
# Predicted:  Flats
# Target Sandals
# Predicted:  Sandals
# Target Heels
# Predicted:  Heels
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Kurtas
# Predicted:  Kurtas
# Target Tshirts
# Predicted:  Tshirts
# Target Sandals
# Predicted:  Sandals
# Target Tshirts
# Predicted:  Tshirts
# Target Shirts
# Predicted:  Shirts
# Target Wallets
# Predicted:  Wallets
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Formal Shoes
# Predicted:  Formal Shoes
# Target Flip Flops
# Predicted:  Flip Flops
# Target Shirts
# Predicted:  Shirts
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Tops
# Predicted:  Tops
# Target Shirts
# Predicted:  Shirts
# Target Flats
# Predicted:  Flats
# Target Tshirts
# Predicted:  Tops
# Target Flip Flops
# Predicted:  Flip Flops
# Target Handbags
# Predicted:  Handbags
# Target Sports Shoes
# Predicted:  Casual Shoes
# Target Sandals
# Predicted:  Sandals
# Target Socks
# Predicted:  Socks
# Target Shirts
# Predicted:  Shirts
# Target Briefs
# Predicted:  Briefs
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Shirts
# Predicted:  Shirts
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Shirts
# Predicted:  Shirts
# Target Tshirts
# Predicted:  Tshirts
# Target Kurtas
# Predicted:  Shirts
# Target Flip Flops
# Predicted:  Flip Flops
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Wallets
# Predicted:  Wallets
# Target Handbags
# Predicted:  Handbags
# Target Tshirts
# Predicted:  Tshirts
# Target Handbags
# Predicted:  Handbags
# Target Tshirts
# Predicted:  Tshirts
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Sandals
# Predicted:  Sandals
# Target Heels
# Predicted:  Heels
# Target Flip Flops
# Predicted:  Flip Flops
# Target Tshirts
# Predicted:  Tshirts
# Target Tops
# Predicted:  Tops
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Shirts
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Briefs
# Predicted:  Briefs
# Target Tshirts
# Predicted:  Tshirts
# Target Socks
# Predicted:  Socks
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tops
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Heels
# Predicted:  Heels
# Target Tshirts
# Predicted:  Tshirts
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Kurtas
# Predicted:  Kurtas
# Target Tshirts
# Predicted:  Tshirts
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Watches
# Predicted:  Watches
# Target Shirts
# Predicted:  Shirts
# Target Belts
# Predicted:  Belts
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Belts
# Predicted:  Belts
# Target Kurtas
# Predicted:  Kurtas
# Target Briefs
# Predicted:  Briefs
# Target Handbags
# Predicted:  Wallets
# Target Tshirts
# Predicted:  Tshirts
# Target Casual Shoes
# Predicted:  Sports Shoes
# Target Handbags
# Predicted:  Handbags
# Target Tops
# Predicted:  Tshirts
# Target Kurtas
# Predicted:  Kurtas
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Tops
# Predicted:  Tops
# Target Tshirts
# Predicted:  Tshirts
# Target Shirts
# Predicted:  Shirts
# Target Dresses
# Predicted:  Dresses
# Target Tshirts
# Predicted:  Kurtas
# Target Tshirts
# Predicted:  Tshirts
# Target Belts
# Predicted:  Belts
# Target Belts
# Predicted:  Belts
# Target Shirts
# Predicted:  Shirts
# Target Heels
# Predicted:  Heels
# Target Tshirts
# Predicted:  Tshirts
# Target Shirts
# Predicted:  Shirts
# Target Sandals
# Predicted:  Sandals
# Target Kurtas
# Predicted:  Kurtas
# Target Tops
# Predicted:  Dresses
# Target Shirts
# Predicted:  Shirts
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Tshirts
# Predicted:  Tshirts
# Target Wallets
# Predicted:  Wallets
# Target Shirts
# Predicted:  Shirts
# Target Tshirts
# Predicted:  Tops
# Target Kurtas
# Predicted:  Kurtas
# Target Shirts
# Predicted:  Shirts
# Target Tshirts
# Predicted:  Tshirts
# Target Tops
# Predicted:  Tops
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Tshirts
# Predicted:  Tshirts
# Target Handbags
# Predicted:  Handbags
# Target Heels
# Predicted:  Heels
# Target Shirts
# Predicted:  Shirts
# Target Tshirts
# Predicted:  Tshirts
# Target Sandals
# Predicted:  Sandals
# Target Wallets
# Predicted:  Wallets
# Target Tshirts
# Predicted:  Tops
# Target Flats
# Predicted:  Flats
# Target Wallets
# Predicted:  Wallets
# Target Kurtas
# Predicted:  Kurtas
# Target Formal Shoes
# Predicted:  Formal Shoes
# Target Tshirts
# Predicted:  Tops
# Target Shirts
# Predicted:  Shirts
# Target Tshirts
# Predicted:  Tshirts
# Target Shirts
# Predicted:  Shirts
# Target Heels
# Predicted:  Heels
# Target Shirts
# Predicted:  Shirts
# Target Heels
# Predicted:  Heels
# Target Handbags
# Predicted:  Handbags
# Target Handbags
# Predicted:  Handbags
# Target Tshirts
# Predicted:  Tshirts
# Target Tops
# Predicted:  Tops
# Target Tshirts
# Predicted:  Tshirts
# Target Kurtas
# Predicted:  Kurtas
# Target Casual Shoes
# Predicted:  Sports Shoes
# Target Tshirts
# Predicted:  Tshirts
# Target Wallets
# Predicted:  Wallets
# Target Flats
# Predicted:  Sandals
# Target Tshirts
# Predicted:  Tshirts
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Watches
# Predicted:  Watches
# Target Casual Shoes
# Predicted:  Heels
# Target Shirts
# Predicted:  Shirts
# Target Belts
# Predicted:  Belts
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Handbags
# Predicted:  Handbags
# Target Flip Flops
# Predicted:  Flip Flops
# Target Socks
# Predicted:  Socks
# Target Flip Flops
# Predicted:  Flip Flops
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Tops
# Predicted:  Tops
# Target Shirts
# Predicted:  Shirts
# Target Tshirts
# Predicted:  Tshirts
# Target Briefs
# Predicted:  Briefs
# Target Tshirts
# Predicted:  Tshirts
# Target Handbags
# Predicted:  Handbags
# Target Flats
# Predicted:  Flats
# Target Sandals
# Predicted:  Sandals
# Target Handbags
# Predicted:  Tops
# Target Tops
# Predicted:  Tops
# Target Tshirts
# Predicted:  Tshirts
# Target Flip Flops
# Predicted:  Flip Flops
# Target Flip Flops
# Predicted:  Flip Flops
# Target Shirts
# Predicted:  Shirts
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Tshirts
# Predicted:  Tshirts
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Tshirts
# Predicted:  Tshirts
# Target Shirts
# Predicted:  Shirts
# Target Heels
# Predicted:  Heels
# Target Shirts
# Predicted:  Shirts
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Handbags
# Predicted:  Handbags
# Target Tops
# Predicted:  Dresses
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Handbags
# Predicted:  Handbags
# Target Tshirts
# Predicted:  Tshirts
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Dresses
# Predicted:  Dresses
# Target Shirts
# Predicted:  Shirts
# Target Shirts
# Predicted:  Shirts
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Shirts
# Predicted:  Shirts
# Target Briefs
# Predicted:  Briefs
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Heels
# Predicted:  Heels
# Target Shirts
# Predicted:  Shirts
# Target Sandals
# Predicted:  Sandals
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Formal Shoes
# Predicted:  Casual Shoes
# Target Shirts
# Predicted:  Shirts
# Target Belts
# Predicted:  Belts
# Target Handbags
# Predicted:  Handbags
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Watches
# Predicted:  Watches
# Target Tshirts
# Predicted:  Tshirts
# Target Shirts
# Predicted:  Shirts
# Target Tops
# Predicted:  Tops
# Target Tshirts
# Predicted:  Shirts
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Heels
# Predicted:  Heels
# Target Flip Flops
# Predicted:  Flip Flops
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Tops
# Predicted:  Tops
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Tops
# Predicted:  Tops
# Target Belts
# Predicted:  Belts
# Target Sports Shoes
# Predicted:  Casual Shoes
# Target Tshirts
# Predicted:  Tshirts
# Target Shirts
# Predicted:  Shirts
# Target Belts
# Predicted:  Belts
# Target Flip Flops
# Predicted:  Flip Flops
# Target Shirts
# Predicted:  Shirts
# Target Tshirts
# Predicted:  Tops
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Shirts
# Predicted:  Shirts
# Target Tshirts
# Predicted:  Tshirts
# Target Kurtas
# Predicted:  Kurtas
# Target Shirts
# Predicted:  Shirts
# Target Flats
# Predicted:  Flats
# Target Tshirts
# Predicted:  Tops
# Target Tshirts
# Predicted:  Tshirts
# Target Kurtas
# Predicted:  Kurtas
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Tops
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Tops
# Predicted:  Tops
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Tshirts
# Predicted:  Tshirts
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Shirts
# Predicted:  Shirts
# Target Sandals
# Predicted:  Sandals
# Target Belts
# Predicted:  Belts
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Tshirts
# Predicted:  Tshirts
# Target Handbags
# Predicted:  Handbags
# Target Handbags
# Predicted:  Handbags
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Tshirts
# Predicted:  Tshirts
# Target Wallets
# Predicted:  Wallets
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Belts
# Predicted:  Belts
# Target Tshirts
# Predicted:  Tops
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Handbags
# Predicted:  Handbags
# Target Tshirts
# Predicted:  Tshirts
# Target Dresses
# Predicted:  Dresses
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Shirts
# Predicted:  Shirts
# Target Watches
# Predicted:  Watches
# Target Handbags
# Predicted:  Handbags
# Target Shirts
# Predicted:  Shirts
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Belts
# Predicted:  Belts
# Target Belts
# Predicted:  Belts
# Target Formal Shoes
# Predicted:  Formal Shoes
# Target Tops
# Predicted:  Dresses
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Shirts
# Predicted:  Shirts
# Target Shirts
# Predicted:  Shirts
# Target Shirts
# Predicted:  Shirts
# Target Casual Shoes
# Predicted:  Sports Shoes
# Target Tshirts
# Predicted:  Tshirts
# Target Shirts
# Predicted:  Shirts
# Target Tshirts
# Predicted:  Tshirts
# Target Formal Shoes
# Predicted:  Formal Shoes
# Target Tshirts
# Predicted:  Tshirts
# Target Wallets
# Predicted:  Wallets
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Shirts
# Predicted:  Shirts
# Target Tshirts
# Predicted:  Tshirts
# Target Dresses
# Predicted:  Dresses
# Target Handbags
# Predicted:  Handbags
# Target Tshirts
# Predicted:  Tshirts
# Target Briefs
# Predicted:  Briefs
# Target Flip Flops
# Predicted:  Flip Flops
# Target Wallets
# Predicted:  Wallets
# Target Wallets
# Predicted:  Wallets
# Target Tshirts
# Predicted:  Tshirts
# Target Tops
# Predicted:  Tops
# Target Kurtas
# Predicted:  Kurtas
# Target Shirts
# Predicted:  Shirts
# Target Shirts
# Predicted:  Shirts
# Target Tshirts
# Predicted:  Tshirts
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Flats
# Predicted:  Sandals
# Target Tshirts
# Predicted:  Tops
# Target Belts
# Predicted:  Belts
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Heels
# Predicted:  Flats
# Target Sports Shoes
# Predicted:  Casual Shoes
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Casual Shoes
# Predicted:  Sports Shoes
# Target Handbags
# Predicted:  Handbags
# Target Formal Shoes
# Predicted:  Formal Shoes
# Target Handbags
# Predicted:  Handbags
# Target Tshirts
# Predicted:  Tshirts
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Formal Shoes
# Predicted:  Formal Shoes
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Tshirts
# Predicted:  Tops
# Target Shirts
# Predicted:  Shirts
# Target Kurtas
# Predicted:  Kurtas
# Target Tshirts
# Predicted:  Tshirts
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Tops
# Predicted:  Tops
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Handbags
# Predicted:  Handbags
# Target Tshirts
# Predicted:  Tshirts
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Kurtas
# Predicted:  Kurtas
# Target Shirts
# Predicted:  Shirts
# Target Tshirts
# Predicted:  Tshirts
# Target Heels
# Predicted:  Flats
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Casual Shoes
# Predicted:  Sports Shoes
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Tshirts
# Predicted:  Tops
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Flip Flops
# Predicted:  Flip Flops
# Target Sandals
# Predicted:  Sandals
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Wallets
# Predicted:  Wallets
# Target Heels
# Predicted:  Casual Shoes
# Target Tshirts
# Predicted:  Tshirts
# Target Heels
# Predicted:  Heels
# Target Flip Flops
# Predicted:  Flip Flops
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Tshirts
# Predicted:  Tshirts
# Target Shirts
# Predicted:  Shirts
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Shirts
# Predicted:  Shirts
# Target Heels
# Predicted:  Heels
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Shirts
# Predicted:  Shirts
# Target Wallets
# Predicted:  Wallets
# Target Tops
# Predicted:  Tops
# Target Handbags
# Predicted:  Handbags
# Target Shirts
# Predicted:  Shirts
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Shirts
# Predicted:  Shirts
# Target Tops
# Predicted:  Tops
# Target Tshirts
# Predicted:  Tshirts
# Target Handbags
# Predicted:  Handbags
# Target Formal Shoes
# Predicted:  Formal Shoes
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Handbags
# Target Handbags
# Predicted:  Handbags
# Target Shirts
# Predicted:  Shirts
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Shirts
# Predicted:  Shirts
# Target Tshirts
# Predicted:  Tshirts
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Flip Flops
# Predicted:  Flip Flops
# Target Socks
# Predicted:  Socks
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Tshirts
# Predicted:  Tshirts
# Target Sandals
# Predicted:  Sandals
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Handbags
# Predicted:  Handbags
# Target Tshirts
# Predicted:  Tshirts
# Target Shirts
# Predicted:  Shirts
# Target Wallets
# Predicted:  Wallets
# Target Tshirts
# Predicted:  Tops
# Target Belts
# Predicted:  Belts
# Target Sandals
# Predicted:  Flip Flops
# Target Tshirts
# Predicted:  Tshirts
# Target Tops
# Predicted:  Tops
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Handbags
# Predicted:  Handbags
# Target Flip Flops
# Predicted:  Flip Flops
# Target Shirts
# Predicted:  Shirts
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Heels
# Predicted:  Heels
# Target Tshirts
# Predicted:  Tshirts
# Target Shirts
# Predicted:  Shirts
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Kurtas
# Predicted:  Kurtas
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Tops
# Predicted:  Tops
# Target Tops
# Predicted:  Tshirts
# Target Shirts
# Predicted:  Shirts
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tops
# Target Briefs
# Predicted:  Briefs
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Formal Shoes
# Predicted:  Formal Shoes
# Target Flip Flops
# Predicted:  Flip Flops
# Target Shirts
# Predicted:  Shirts
# Target Handbags
# Predicted:  Handbags
# Target Tshirts
# Predicted:  Tshirts
# Target Shirts
# Predicted:  Shirts
# Target Shirts
# Predicted:  Shirts
# Target Tshirts
# Predicted:  Tshirts
# Target Shirts
# Predicted:  Shirts
# Target Tshirts
# Predicted:  Tshirts
# Target Heels
# Predicted:  Flats
# Target Heels
# Predicted:  Heels
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Tshirts
# Predicted:  Tshirts
# Target Heels
# Predicted:  Flats
# Target Shirts
# Predicted:  Shirts
# Target Tshirts
# Predicted:  Tshirts
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Tops
# Predicted:  Tops
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tops
# Target Flip Flops
# Predicted:  Flip Flops
# Target Belts
# Predicted:  Belts
# Target Handbags
# Predicted:  Handbags
# Target Shirts
# Predicted:  Shirts
# Target Handbags
# Predicted:  Handbags
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Shirts
# Predicted:  Shirts
# Target Socks
# Predicted:  Socks
# Target Tshirts
# Predicted:  Tshirts
# Target Shirts
# Predicted:  Shirts
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Formal Shoes
# Predicted:  Formal Shoes
# Target Tshirts
# Predicted:  Tshirts
# Target Wallets
# Predicted:  Wallets
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Flip Flops
# Predicted:  Flip Flops
# Target Casual Shoes
# Predicted:  Sports Shoes
# Target Tshirts
# Predicted:  Tshirts
# Target Heels
# Predicted:  Flats
# Target Shirts
# Predicted:  Shirts
# Target Handbags
# Predicted:  Handbags
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Tshirts
# Predicted:  Tshirts
# Target Sandals
# Predicted:  Sandals
# Target Tshirts
# Predicted:  Tshirts
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Heels
# Predicted:  Heels
# Target Shirts
# Predicted:  Shirts
# Target Tshirts
# Predicted:  Tshirts
# Target Sandals
# Predicted:  Sandals
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Tshirts
# Predicted:  Tshirts
# Target Shirts
# Predicted:  Shirts
# Target Flip Flops
# Predicted:  Sandals
# Target Flip Flops
# Predicted:  Flip Flops
# Target Shirts
# Predicted:  Shirts
# Target Belts
# Predicted:  Belts
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Tshirts
# Predicted:  Tshirts
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Heels
# Predicted:  Heels
# Target Shirts
# Predicted:  Shirts
# Target Wallets
# Predicted:  Wallets
# Target Tshirts
# Predicted:  Tops
# Target Formal Shoes
# Predicted:  Formal Shoes
# Target Tshirts
# Predicted:  Tshirts
# Target Watches
# Predicted:  Watches
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Tshirts
# Predicted:  Tshirts
# Target Kurtas
# Predicted:  Kurtas
# Target Handbags
# Predicted:  Handbags
# Target Tshirts
# Predicted:  Tshirts
# Target Shirts
# Predicted:  Shirts
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Handbags
# Predicted:  Handbags
# Target Shirts
# Predicted:  Shirts
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Shirts
# Predicted:  Shirts
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Shirts
# Predicted:  Shirts
# Target Tshirts
# Predicted:  Tshirts
# Target Tops
# Predicted:  Tshirts
# Target Heels
# Predicted:  Flats
# Target Belts
# Predicted:  Belts
# Target Flats
# Predicted:  Flats
# Target Briefs
# Predicted:  Briefs
# Target Tshirts
# Predicted:  Tshirts
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Belts
# Predicted:  Belts
# Target Shirts
# Predicted:  Shirts
# Target Tshirts
# Predicted:  Tshirts
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Tops
# Predicted:  Tops
# Target Wallets
# Predicted:  Wallets
# Target Sandals
# Predicted:  Casual Shoes
# Target Flip Flops
# Predicted:  Flip Flops
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Flip Flops
# Predicted:  Flip Flops
# Target Flip Flops
# Predicted:  Flip Flops
# Target Shirts
# Predicted:  Shirts
# Target Kurtas
# Predicted:  Kurtas
# Target Tops
# Predicted:  Tops
# Target Tops
# Predicted:  Tops
# Target Shirts
# Predicted:  Shirts
# Target Heels
# Predicted:  Heels
# Target Handbags
# Predicted:  Handbags
# Target Shirts
# Predicted:  Shirts
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Socks
# Predicted:  Socks
# Target Tshirts
# Predicted:  Tshirts
# Target Handbags
# Predicted:  Handbags
# Target Sandals
# Predicted:  Sandals
# Target Shirts
# Predicted:  Shirts
# Target Tshirts
# Predicted:  Tshirts
# Target Formal Shoes
# Predicted:  Formal Shoes
# Target Tshirts
# Predicted:  Tshirts
# Target Shirts
# Predicted:  Shirts
# Target Wallets
# Predicted:  Wallets
# ...
# Predicted:  Kurtas
# Target Tshirts
# Predicted:  Tshirts
# Target Shirts
# Predicted:  Shirts
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Kurtas
# Predicted:  Kurtas
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Handbags
# Predicted:  Handbags
# Target Tshirts
# Predicted:  Tshirts
# Target Wallets
# Predicted:  Wallets
# Target Casual Shoes
# Predicted:  Sports Shoes
# Target Tshirts
# Predicted:  Tshirts
# Target Wallets
# Predicted:  Wallets
# Target Shirts
# Predicted:  Shirts
# Target Tshirts
# Predicted:  Tshirts
# Target Formal Shoes
# Predicted:  Formal Shoes
# Target Tshirts
# Predicted:  Tshirts
# Target Socks
# Predicted:  Shirts
# Target Tshirts
# Predicted:  Tshirts
# Target Flip Flops
# Predicted:  Sandals
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Shirts
# Predicted:  Shirts
# Target Shirts
# Predicted:  Shirts
# Target Shirts
# Predicted:  Shirts
# Target Heels
# Predicted:  Flats
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Heels
# Predicted:  Heels
# Target Tshirts
# Predicted:  Dresses
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Handbags
# Predicted:  Handbags
# Target Wallets
# Predicted:  Wallets
# Target Tshirts
# Predicted:  Tshirts
# Target Kurtas
# Predicted:  Kurtas
# Target Flip Flops
# Predicted:  Flip Flops
# Target Formal Shoes
# Predicted:  Formal Shoes
# Target Tshirts
# Predicted:  Tshirts
# Target Heels
# Predicted:  Heels
# Target Handbags
# Predicted:  Handbags
# Target Tshirts
# Predicted:  Tshirts
# Target Handbags
# Predicted:  Handbags
# Target Flip Flops
# Predicted:  Flip Flops
# Target Kurtas
# Predicted:  Kurtas
# Target Tshirts
# Predicted:  Tshirts
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Kurtas
# Predicted:  Kurtas
# Target Tshirts
# Predicted:  Tshirts
# Target Briefs
# Predicted:  Briefs
# Target Kurtas
# Predicted:  Kurtas
# Target Tshirts
# Predicted:  Tops
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Kurtas
# Predicted:  Kurtas
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Sandals
# Predicted:  Sandals
# Target Shirts
# Predicted:  Shirts
# Target Shirts
# Predicted:  Shirts
# Target Tshirts
# Predicted:  Tshirts
# Target Shirts
# Predicted:  Shirts
# Target Handbags
# Predicted:  Handbags
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Heels
# Predicted:  Heels
# Target Briefs
# Predicted:  Briefs
# Target Sandals
# Predicted:  Sandals
# Target Tshirts
# Predicted:  Tshirts
# Target Kurtas
# Predicted:  Dresses
# Target Formal Shoes
# Predicted:  Formal Shoes
# Target Shirts
# Predicted:  Shirts
# Target Tshirts
# Predicted:  Tshirts
# Target Shirts
# Predicted:  Shirts
# Target Dresses
# Predicted:  Dresses
# Target Handbags
# Predicted:  Handbags
# Target Sports Shoes
# Predicted:  Casual Shoes
# Target Tshirts
# Predicted:  Tshirts
# Target Shirts
# Predicted:  Shirts
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Kurtas
# Predicted:  Kurtas
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Formal Shoes
# Predicted:  Formal Shoes
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Shirts
# Predicted:  Shirts
# Target Tshirts
# Predicted:  Tshirts
# Target Shirts
# Predicted:  Shirts
# Target Dresses
# Predicted:  Dresses
# Target Shirts
# Predicted:  Shirts
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Kurtas
# Predicted:  Kurtas
# Target Shirts
# Predicted:  Shirts
# Target Shirts
# Predicted:  Shirts
# Target Tshirts
# Predicted:  Tshirts
# Target Formal Shoes
# Predicted:  Formal Shoes
# Target Shirts
# Predicted:  Shirts
# Target Tshirts
# Predicted:  Tshirts
# Target Belts
# Predicted:  Belts
# Target Tshirts
# Predicted:  Tshirts
# Target Briefs
# Predicted:  Briefs
# Target Belts
# Predicted:  Belts
# Target Formal Shoes
# Predicted:  Formal Shoes
# Target Tshirts
# Predicted:  Tops
# Target Shirts
# Predicted:  Shirts
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Casual Shoes
# Predicted:  Sports Shoes
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Shirts
# Predicted:  Shirts
# Target Sandals
# Predicted:  Sandals
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Flip Flops
# Predicted:  Flip Flops
# Target Tshirts
# Predicted:  Tshirts
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Casual Shoes
# Predicted:  Sports Shoes
# Target Tshirts
# Predicted:  Tshirts
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Tshirts
# Predicted:  Tshirts
# Target Kurtas
# Predicted:  Tops
# Target Sandals
# Predicted:  Sandals
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Handbags
# Predicted:  Handbags
# Target Shirts
# Predicted:  Shirts
# Target Tshirts
# Predicted:  Tshirts
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Formal Shoes
# Predicted:  Formal Shoes
# Target Kurtas
# Predicted:  Kurtas
# Target Tshirts
# Predicted:  Tshirts
# Target Heels
# Predicted:  Flats
# Target Tshirts
# Predicted:  Tshirts
# Target Handbags
# Predicted:  Handbags
# Target Socks
# Predicted:  Socks
# Target Casual Shoes
# Predicted:  Sports Shoes
# Target Tshirts
# Predicted:  Tshirts
# Target Tops
# Predicted:  Tops
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tops
# Target Heels
# Predicted:  Heels
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Handbags
# Predicted:  Handbags
# Target Belts
# Predicted:  Belts
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Shirts
# Predicted:  Shirts
# Target Tshirts
# Predicted:  Tshirts
# Target Shirts
# Predicted:  Shirts
# Target Tshirts
# Predicted:  Tshirts
# Target Tops
# Predicted:  Tops
# Target Tshirts
# Predicted:  Tshirts
# Target Wallets
# Predicted:  Wallets
# Target Shirts
# Predicted:  Shirts
# Target Tshirts
# Predicted:  Tshirts
# Target Formal Shoes
# Predicted:  Formal Shoes
# Target Socks
# Predicted:  Socks
# Target Flip Flops
# Predicted:  Flip Flops
# Target Tshirts
# Predicted:  Tshirts
# Target Kurtas
# Predicted:  Kurtas
# Target Shirts
# Predicted:  Shirts
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tops
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Tshirts
# Predicted:  Tshirts
# Target Kurtas
# Predicted:  Kurtas
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Shirts
# Predicted:  Shirts
# Target Shirts
# Predicted:  Shirts
# Target Kurtas
# Predicted:  Kurtas
# Target Briefs
# Predicted:  Briefs
# Target Handbags
# Predicted:  Handbags
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Tshirts
# Predicted:  Tshirts
# Target Shirts
# Predicted:  Shirts
# Target Tshirts
# Predicted:  Tshirts
# Target Heels
# Predicted:  Flats
# Target Handbags
# Predicted:  Handbags
# Target Tshirts
# Predicted:  Tshirts
# Target Tops
# Predicted:  Tops
# Target Tshirts
# Predicted:  Tshirts
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Shirts
# Predicted:  Shirts
# Target Kurtas
# Predicted:  Kurtas
# Target Tshirts
# Predicted:  Tshirts
# Target Wallets
# Predicted:  Wallets
# Target Casual Shoes
# Predicted:  Sports Shoes
# Target Shirts
# Predicted:  Shirts
# Target Flip Flops
# Predicted:  Flip Flops
# Target Casual Shoes
# Predicted:  Sports Shoes
# Target Tshirts
# Predicted:  Tshirts
# Target Shirts
# Predicted:  Shirts
# Target Kurtas
# Predicted:  Kurtas
# Target Tshirts
# Predicted:  Tshirts
# Target Heels
# Predicted:  Heels
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Heels
# Predicted:  Heels
# Target Casual Shoes
# Predicted:  Formal Shoes
# Target Shirts
# Predicted:  Shirts
# Target Socks
# Predicted:  Socks
# Target Tshirts
# Predicted:  Tshirts
# Target Kurtas
# Predicted:  Kurtas
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Handbags
# Predicted:  Handbags
# Target Shirts
# Predicted:  Shirts
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Belts
# Predicted:  Belts
# Target Tshirts
# Predicted:  Tshirts
# Target Handbags
# Predicted:  Handbags
# Target Wallets
# Predicted:  Handbags
# Target Heels
# Predicted:  Flats
# Target Handbags
# Predicted:  Handbags
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tops
# Target Flip Flops
# Predicted:  Flip Flops
# Target Tshirts
# Predicted:  Tshirts
# Target Flip Flops
# Predicted:  Flip Flops
# Target Shirts
# Predicted:  Shirts
# Target Tshirts
# Predicted:  Tops
# Target Tshirts
# Predicted:  Tshirts
# Target Kurtas
# Predicted:  Kurtas
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Flip Flops
# Predicted:  Flip Flops
# Target Sandals
# Predicted:  Sandals
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Heels
# Predicted:  Heels
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Tshirts
# Predicted:  Tops
# Target Sandals
# Predicted:  Sandals
# Target Flip Flops
# Predicted:  Flip Flops
# Target Tshirts
# Predicted:  Tshirts
# Target Kurtas
# Predicted:  Kurtas
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Tshirts
# Predicted:  Tshirts
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Socks
# Predicted:  Socks
# Target Tshirts
# Predicted:  Tshirts
# Target Sandals
# Predicted:  Sandals
# Target Casual Shoes
# Predicted:  Sports Shoes
# Target Kurtas
# Predicted:  Kurtas
# Target Shirts
# Predicted:  Shirts
# Target Shirts
# Predicted:  Shirts
# Target Shirts
# Predicted:  Shirts
# Target Handbags
# Predicted:  Wallets
# Target Tshirts
# Predicted:  Tshirts
# Target Tops
# Predicted:  Tops
# Target Casual Shoes
# Predicted:  Formal Shoes
# Target Tops
# Predicted:  Shirts
# Target Tshirts
# Predicted:  Tshirts
# Target Briefs
# Predicted:  Briefs
# Target Kurtas
# Predicted:  Kurtas
# Target Belts
# Predicted:  Belts
# Target Tops
# Predicted:  Tops
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Tshirts
# Predicted:  Tshirts
# Target Tops
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Kurtas
# Predicted:  Kurtas
# Target Shirts
# Predicted:  Shirts
# Target Wallets
# Predicted:  Wallets
# Target Shirts
# Predicted:  Shirts
# Target Belts
# Predicted:  Belts
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tops
# Target Sandals
# Predicted:  Flip Flops
# Target Tshirts
# Predicted:  Tshirts
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Tops
# Predicted:  Shirts
# Target Tshirts
# Predicted:  Tshirts
# Target Shirts
# Predicted:  Shirts
# Target Tshirts
# Predicted:  Tshirts
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Handbags
# Predicted:  Handbags
# Target Tshirts
# Predicted:  Tshirts
# Target Shirts
# Predicted:  Shirts
# Target Tshirts
# Predicted:  Tshirts
# Target Shirts
# Predicted:  Shirts
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Sports Shoes
# Predicted:  Casual Shoes
# Target Tshirts
# Predicted:  Tshirts
# Target Shirts
# Predicted:  Shirts
# Target Tshirts
# Predicted:  Tshirts
# Target Handbags
# Predicted:  Handbags
# Target Tshirts
# Predicted:  Tshirts
# Target Heels
# Predicted:  Flats
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Shirts
# Predicted:  Shirts
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Shirts
# Predicted:  Shirts
# Target Heels
# Predicted:  Heels
# Target Wallets
# Predicted:  Wallets
# Target Tshirts
# Predicted:  Tshirts
# Target Kurtas
# Predicted:  Kurtas
# Target Sports Shoes
# Predicted:  Casual Shoes
# Target Briefs
# Predicted:  Briefs
# Target Tshirts
# Predicted:  Tshirts
# Target Formal Shoes
# Predicted:  Formal Shoes
# Target Flip Flops
# Predicted:  Flip Flops
# Target Shirts
# Predicted:  Shirts
# Target Handbags
# Predicted:  Handbags
# Target Shirts
# Predicted:  Shirts
# Target Tshirts
# Predicted:  Tshirts
# Target Heels
# Predicted:  Heels
# Target Tshirts
# Predicted:  Tshirts
# Target Tops
# Predicted:  Tops
# Target Kurtas
# Predicted:  Kurtas
# Target Shirts
# Predicted:  Shirts
# Target Heels
# Predicted:  Flats
# Target Tops
# Predicted:  Tops
# Target Belts
# Predicted:  Belts
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Shirts
# Predicted:  Shirts
# Target Tshirts
# Predicted:  Tshirts
# Target Shirts
# Predicted:  Shirts
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Formal Shoes
# Predicted:  Formal Shoes
# Target Handbags
# Predicted:  Handbags
# Target Briefs
# Predicted:  Briefs
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Kurtas
# Predicted:  Kurtas
# Target Heels
# Predicted:  Heels
# Target Tshirts
# Predicted:  Tshirts
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Shirts
# Predicted:  Shirts
# Target Shirts
# Predicted:  Shirts
# Target Heels
# Predicted:  Heels
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Belts
# Predicted:  Belts
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Casual Shoes
# Predicted:  Sports Shoes
# Target Tshirts
# Predicted:  Tshirts
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Tshirts
# Predicted:  Tshirts
# Target Sandals
# Predicted:  Flip Flops
# Target Sunglasses
# Predicted:  Sunglasses
# Target Belts
# Predicted:  Belts
# Target Kurtas
# Predicted:  Kurtas
# Target Wallets
# Predicted:  Wallets
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tops
# Target Tshirts
# Predicted:  Tshirts
# Target Handbags
# Predicted:  Handbags
# Target Shirts
# Predicted:  Shirts
# Target Tops
# Predicted:  Tops
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Tshirts
# Predicted:  Sarees
# Target Watches
# Predicted:  Watches
# Target Tshirts
# Predicted:  Tshirts
# Target Briefs
# Predicted:  Briefs
# Target Shirts
# Predicted:  Shirts
# Target Belts
# Predicted:  Belts
# Target Kurtas
# Predicted:  Kurtas
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Tops
# Predicted:  Dresses
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Tshirts
# Predicted:  Tshirts
# Target Tops
# Predicted:  Tops
# Target Kurtas
# Predicted:  Dresses
# Target Sandals
# Predicted:  Sandals
# Target Sunglasses
# Predicted:  Sunglasses
# Target Shirts
# Predicted:  Shirts
# Target Tshirts
# Predicted:  Tshirts
# Target Shirts
# Predicted:  Shirts
# Target Tshirts
# Predicted:  Tshirts
# Target Dresses
# Predicted:  Dresses
# Target Tshirts
# Predicted:  Tshirts
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Tshirts
# Predicted:  Tshirts
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Briefs
# Predicted:  Briefs
# Target Kurtas
# Predicted:  Kurtas
# Target Briefs
# Predicted:  Wallets
# Target Tshirts
# Predicted:  Tshirts
# Target Kurtas
# Predicted:  Kurtas
# Target Casual Shoes
# Predicted:  Sports Shoes
# Target Sandals
# Predicted:  Sandals
# Target Belts
# Predicted:  Belts
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Tshirts
# Predicted:  Tshirts
# Target Sports Shoes
# Predicted:  Sports Shoes
# Target Belts
# Predicted:  Belts
# Target Handbags
# Predicted:  Handbags
# Target Heels
# Predicted:  Flats
# Target Tshirts
# Predicted:  Tshirts
# Target Tshirts
# Predicted:  Tshirts
# Target Casual Shoes
# Predicted:  Casual Shoes
# Target Flip Flops
# Predicted:  Flip Flops
# Target Tshirts
# Predicted:  Tshirts
# Total Instances:  14034
# Overall Accuracy:  0.893971782813168
# class:
#  Shirts
# top1:  0.9894585529468136
# top5:  1.0
# class:
#  Tshirts
# top1:  0.9103544127866574
# top5:  0.9972202918693537
# class:
#  Casual Shoes
# top1:  0.7544401544401544
# top5:  0.9953667953667954
# class:
#  Flip Flops
# top1:  0.8648648648648649
# top5:  0.9852579852579852
# class:
#  Sandals
# top1:  0.861904761904762
# top5:  0.9952380952380953
# class:
#  Formal Shoes
# top1:  0.9388489208633094
# top5:  0.9856115107913669
# class:
#  Handbags
# top1:  0.9840637450199203
# top5:  0.9960159362549801
# class:
#  Kurtas
# top1:  0.9517045454545454
# top5:  0.9971590909090909
# class:
#  Belts
# top1:  0.9906542056074766
# top5:  0.9906542056074766
# class:
#  Flats
# top1:  0.4430379746835443
# top5:  0.9746835443037974
# class:
#  Sports Shoes
# top1:  0.9012987012987013
# top5:  0.9965367965367965
# class:
#  Heels
# top1:  0.635036496350365
# top5:  0.9981751824817519
# class:
#  Wallets
# top1:  0.9761904761904762
# top5:  1.0
# class:
#  Tops
# top1:  0.7795163584637269
# top5:  0.9985775248933144
# class:
#  Briefs
# top1:  0.9679144385026738
# top5:  1.0
# class:
#  Dresses
# top1:  0.956989247311828
# top5:  1.0
# class:
#  Socks
# top1:  0.9613259668508287
# top5:  0.994475138121547
# class:
#  Watches
# top1:  1.0
# top5:  1.0
# class:
#  Sunglasses
# top1:  1.0
# top5:  1.0
